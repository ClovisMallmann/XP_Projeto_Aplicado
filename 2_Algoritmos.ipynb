# %% [markdown]
# <a href="https://colab.research.google.com/github/ClovisMallmann/XP_Projeto_Aplicado/blob/main/2_Algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Carregamendo do Google drive para leitura dos Datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importando bibliotecas

import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# # 1 - Importando a Base de dados e tratando, caso precise.

# %%
Dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/Base_dados.csv', sep=';', encoding='utf8')

# %%
Dados.head()
# Out:
#                                    Remedios  Cliente_id          Nome  idade  \
# 0                              Amoxicilina;           1  Lars Maynard     78
# 1  Amoxicilina; Escitalopram; Azitromicina;           2   Zane Mullen     70
# 2                              Amoxicilina;           4  Ignacia Pugh     73
# 3                              Amoxicilina;           4  Ignacia Pugh     73
# 4                              Amoxicilina;           4  Ignacia Pugh     73
#
#         sexo  Uf Escolaridade  Renda   Civil                Sintomas  \
# 0   Feminino  MA        Medio   6050  Casado  Incontinencia_urinaria
# 1   Feminino  RS     Primario   6866   Viuvo                 Insonia
# 2  Masculino  MA     Superior   4567  Casado                  Normal
# 3  Masculino  MA     Superior   4567  Casado                  Vomito
# 4  Masculino  MA     Superior   4567  Casado       Lapsos_de_memoria
#
#          Data
# 0  2022-05-08
# 1  2021-09-19
# 2  2022-10-19
# 3  2021-12-02
# 4  2022-05-16

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Remedios      80 non-null     object
#  1   Cliente_id    80 non-null     int64
#  2   Nome          80 non-null     object
#  3   idade         80 non-null     int64
#  4   sexo          80 non-null     object
#  5   Uf            80 non-null     object
#  6   Escolaridade  80 non-null     object
#  7   Renda         80 non-null     int64
#  8   Civil         80 non-null     object
#  9   Sintomas      80 non-null     object
#  10  Data          80 non-null     object
# dtypes: int64(3), object(8)
# memory usage: 7.0+ KB

# %%
#Convertendo o dataframe de forma automática para os Dtypes adequados!

Dados = Dados.convert_dtypes()

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Remedios      80 non-null     string
#  1   Cliente_id    80 non-null     Int64
#  2   Nome          80 non-null     string
#  3   idade         80 non-null     Int64
#  4   sexo          80 non-null     string
#  5   Uf            80 non-null     string
#  6   Escolaridade  80 non-null     string
#  7   Renda         80 non-null     Int64
#  8   Civil         80 non-null     string
#  9   Sintomas      80 non-null     string
#  10  Data          80 non-null     string
# dtypes: Int64(3), string(8)
# memory usage: 7.2 KB

# %%
#Trando a coluna Data

Dados['Data'] = pd.to_datetime(Dados['Data'])

# %%
Dados.info()

# %% [markdown]
# ## **2 - Prontificação a base de dados para estudos**

# %%
Dados.head(20)
# Out:
#                                              Remedios  Cliente_id  \
# 0                                        Amoxicilina;           1
# 1            Amoxicilina; Escitalopram; Azitromicina;           2
# 2                                        Amoxicilina;           4
# 3                                        Amoxicilina;           4
# 4                                        Amoxicilina;           4
# 5   Amoxicilina; Escitalopram; Azitromicina; Cefal...           8
# 6   Amoxicilina; Escitalopram; Azitromicina; Cefal...           8
# 7            Amoxicilina; Escitalopram; Azitromicina;          10
# 8            Amoxicilina; Escitalopram; Azitromicina;          10
# 9            Amoxicilina; Escitalopram; Azitromicina;          12
# 10                                       Amoxicilina;          13
# 11  Amoxicilina; Escitalopram; Azitromicina; Cefal...          19
# 12           Amoxicilina; Escitalopram; Azitromicina;          21
# 13                                       Amoxicilina;          22
# 14                                       Amoxicilina;          22
# 15                                       Amoxicilina;          22
# 16  Amoxicilina; Escitalopram; Azitromicina; Cefal...          24
# 17  Amoxicilina; Escitalopram; Azitromicina; Cefal...          24
# 18                         Amoxicilina; Escitalopram;          25
# 19           Amoxicilina; Escitalopram; Azitromicina;          26
#
#              Nome  idade       sexo  Uf Escolaridade  Renda     Civil  \
# 0    Lars Maynard     78   Feminino  MA        Medio   6050    Casado
# 1     Zane Mullen     70   Feminino  RS     Primario   6866     Viuvo
# 2    Ignacia Pugh     73  Masculino  MA     Superior   4567    Casado
# 3    Ignacia Pugh     73  Masculino  MA     Superior   4567    Casado
# 4    Ignacia Pugh     73  Masculino  MA     Superior   4567    Casado
# 5   Kylee Leonard     70  Masculino  MG     Superior   5854    Casado
# 6   Kylee Leonard     70  Masculino  MG     Superior   5854    Casado
# 7    Samuel Petty     97   Feminino  RJ     Primario   5688    Casado
# 8    Samuel Petty     97   Feminino  RJ     Primario   5688    Casado
# 9     Dolan Avery     94  Masculino  SC        Medio   6071  Solteiro
# 10   Zeus Hartman     69  Masculino  RS     Superior   7102     Viuvo
# 11     Orla Marsh     93   Feminino  SP     Superior   8036  Solteiro
# 12  Raymond Hines     85   Feminino  PB     Superior   7194    Casado
# 13   Cairo Kramer     88   Feminino  RS     Primario   6942    Casado
# 14   Cairo Kramer     88   Feminino  RS     Primario   6942    Casado
# 15   Cairo Kramer     88   Feminino  RS     Primario   6942    Casado
# 16     Kibo Morse     73  Masculino  CE     Primario   6970    Casado
# 17     Kibo Morse     73  Masculino  CE     Primario   6970    Casado
# 18    Hayley Pena     88   Feminino  RS     Primario   3284    Casado
# 19   Yasir Talley     74   Feminino  MG     Primario   4864    Casado
#
#                   Sintomas       Data
# 0   Incontinencia_urinaria 2022-05-08
# 1                  Insonia 2021-09-19
# 2                   Normal 2022-10-19
# 3                   Vomito 2021-12-02
# 4        Lapsos_de_memoria 2022-05-16
# 5            Agressividade 2021-04-28
# 6            Agressividade 2022-11-15
# 7                   Normal 2022-07-10
# 8                   Vomito 2020-10-31
# 9   Incontinencia_urinaria 2020-10-29
# 10                  Normal 2022-10-23
# 11       Lapsos_de_memoria 2020-11-28
# 12       Lapsos_de_memoria 2020-08-29
# 13  Incontinencia_urinaria 2020-10-26
# 14           Agressividade 2022-02-03
# 15       Quedas_de_pressao 2020-08-05
# 16                 Insonia 2021-09-01
# 17           Agressividade 2021-12-12
# 18                  Normal 2020-05-23
# 19                 Insonia 2020-09-10

# %% [markdown]
# ## **3 - Correlação**

# %% [markdown]
# **3.1 - Preparação**

# %%
#Classificando os dados das colunas sexo, UF, Escolaridade, Civil, Sintomas

sexo_class = {'Masculino':'1','Feminino':'2'}

uf_class = {'RO':'1','AC':'2','AM':'3','RR':'4','PA':'5','AP':'6','TO':'7','MA':'8','PI':'9','CE':'10','RN':'11',
            'PB':'12','PE':'13','AL':'14','SE':'15','BA':'16','MG':'17','ES':'18','RJ':'19','SP':'20',
            'PR':'21','SC':'22','RS':'23','MS':'24','MT':'25','GO':'26','DF':'27'
            }


Escolaridade_class = {'Primario':1,'Medio':2,'Superior':3}

Civil_class = {'Solteiro':1,'Casado':2,'Viuvo':3,'Separado':4}

Sintomas_class = {'Normal':1,'Insonia':2,'Agressividade':3,'Quedas_de_pressao':4,'Lapsos_de_memoria':5,'Incontinencia_urinaria':6,'Vomito':7}

# %%
#Alterando os dados das colunas

Dados['sexo'] = Dados['sexo'].map(sexo_class)
Dados['Uf'] = Dados['Uf'].map(uf_class)
Dados['Escolaridade'] = Dados['Escolaridade'].map(Escolaridade_class)
Dados['Civil'] = Dados['Civil'].map(Civil_class)
Dados['Sintomas'] = Dados['Sintomas'].map(Sintomas_class)
Dados.head(10)
# Out:
#                                             Remedios  Cliente_id  \
# 0                                       Amoxicilina;           1
# 1           Amoxicilina; Escitalopram; Azitromicina;           2
# 2                                       Amoxicilina;           4
# 3                                       Amoxicilina;           4
# 4                                       Amoxicilina;           4
# 5  Amoxicilina; Escitalopram; Azitromicina; Cefal...           8
# 6  Amoxicilina; Escitalopram; Azitromicina; Cefal...           8
# 7           Amoxicilina; Escitalopram; Azitromicina;          10
# 8           Amoxicilina; Escitalopram; Azitromicina;          10
# 9           Amoxicilina; Escitalopram; Azitromicina;          12
#
#             Nome  idade sexo  Uf  Escolaridade  Renda  Civil  Sintomas  \
# 0   Lars Maynard     78    2   8             2   6050      2         6
# 1    Zane Mullen     70    2  23             1   6866      3         2
# 2   Ignacia Pugh     73    1   8             3   4567      2         1
# 3   Ignacia Pugh     73    1   8             3   4567      2         7
# 4   Ignacia Pugh     73    1   8             3   4567      2         5
# 5  Kylee Leonard     70    1  17             3   5854      2         3
# 6  Kylee Leonard     70    1  17             3   5854      2         3
# 7   Samuel Petty     97    2  19             1   5688      2         1
# 8   Samuel Petty     97    2  19             1   5688      2         7
# 9    Dolan Avery     94    1  22             2   6071      1         6
#
#         Data
# 0 2022-05-08
# 1 2021-09-19
# 2 2022-10-19
# 3 2021-12-02
# 4 2022-05-16
# 5 2021-04-28
# 6 2022-11-15
# 7 2022-07-10
# 8 2020-10-31
# 9 2020-10-29

# %%
#Verificando os tipos de dados das colunas
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Remedios      80 non-null     string
#  1   Cliente_id    80 non-null     Int64
#  2   Nome          80 non-null     string
#  3   idade         80 non-null     Int64
#  4   sexo          80 non-null     object
#  5   Uf            80 non-null     object
#  6   Escolaridade  80 non-null     int64
#  7   Renda         80 non-null     Int64
#  8   Civil         80 non-null     int64
#  9   Sintomas      80 non-null     int64
#  10  Data          80 non-null     datetime64[ns]
# dtypes: Int64(3), datetime64[ns](1), int64(3), object(2), string(2)
# memory usage: 7.2+ KB

# %%
#Convertendo as colunas sexo e Uf para os formatos adequados adequados!

Dados['sexo'] = pd.to_numeric(Dados['sexo'])
Dados['Uf'] = pd.to_numeric(Dados['Uf'])

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Remedios      80 non-null     string
#  1   Cliente_id    80 non-null     Int64
#  2   Nome          80 non-null     string
#  3   idade         80 non-null     Int64
#  4   sexo          80 non-null     int64
#  5   Uf            80 non-null     int64
#  6   Escolaridade  80 non-null     Int64
#  7   Renda         80 non-null     Int64
#  8   Civil         80 non-null     Int64
#  9   Sintomas      80 non-null     Int64
#  10  Data          80 non-null     datetime64[ns]
# dtypes: Int64(6), datetime64[ns](1), int64(2), string(2)
# memory usage: 7.5 KB

# %%
Dados.head(10)
