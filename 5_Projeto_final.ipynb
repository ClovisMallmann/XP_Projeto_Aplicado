# %% [markdown]
# <a href="https://colab.research.google.com/github/ClovisMallmann/XP_Projeto_Aplicado/blob/main/5_Projeto_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# !apt-get -y install mysql-server
# !service mysql start
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /usr/local/lib/python3.10/dist-packages (from mysql-connector-python) (4.21.12)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mysql-server is already the newest version (8.0.35-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
#  * Starting MySQL database server mysqld
#    ...done.

# %%
# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH 'mysql_native_password' BY 'root';FLUSH PRIVILEGES;"
# Out:
# ERROR 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
import mysql.connector

# Create a connection to the MySQL server
conn = mysql.connector.connect(user='root', password='root', host='localhost')

# Create a cursor to interact with the MySQL server
cursor = conn.cursor()

# %% [markdown]
# # **1 - Criando o BD "Base_dados"**

# %%
# Create a new database named 'Base_dados'
cursor.execute("CREATE DATABASE IF NOT EXISTS Base_dados")

# Switch to the 'Base_dados' database
cursor.execute("USE Base_dados")

# %% [markdown]
# ***1.1 - Criar tab_clientes***

# %%
conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

cursor.execute('''
DROP TABLE IF EXISTS `tab_clientes`;

CREATE TABLE `tab_clientes` (
  `id` mediumint(8) unsigned NOT NULL auto_increment,
  `Cliente_id` mediumint,
  `Nome` varchar(255) default NULL,
  `Idade` mediumint default NULL,
  `Uf` varchar(50) default NULL,
  `Escolaridade` TEXT default NULL,
  `Renda` mediumint default NULL,
  `Civil` TEXT default NULL,
  PRIMARY KEY (`id`)
) AUTO_INCREMENT=1;
''')

# %%
#Dados aleatórios para popular a tabela clientes
inserir_clientes = [
    (1,"Roth May",82,"RS","Medio",6515,"Separado"),
  (2,"Sharon Hebert",70,"PE","Medio",5943,"Separado"),
  (3,"Felix Cochran",73,"PR","Medio",6264,"Casado"),
  (4,"Xanthus Schwartz",71,"GO","Medio",4062,"Solteiro"),
  (5,"Vielka Mcintosh",61,"GO","Medio",8316,"Viuvo"),
  (6,"Ivor Alvarez",60,"PR","Primario",4379,"Casado"),
  (7,"Jordan Mcdonald",78,"SP","Medio",4740,"Casado"),
  (8,"Denton Cochran",80,"SC","Medio",4569,"Casado"),
  (9,"Caesar Hardin",95,"CE","Medio",7315,"Viuvo"),
  (10,"Jack Dotson",90,"MA","Primario",2985,"Separado"),
  (11,"Clark Head",98,"BA","Superior",4370,"Separado"),
  (12,"Sage Schmidt",61,"CE","Primario",5987,"Separado"),
  (13,"Castor Robbins",89,"PB","Superior",6707,"Casado"),
  (14,"Drake Frank",95,"PB","Medio",6091,"Casado"),
  (15,"Jordan Berry",94,"SC","Medio",7184,"Casado"),
  (16,"Dawn Knight",93,"CE","Primario",6481,"Casado"),
  (17,"Savannah Branch",86,"SP","Primario",5874,"Solteiro"),
  (18,"Declan Cruz",78,"PA","Medio",8040,"Separado"),
  (19,"Leilani Mcdaniel",64,"PA","Primario",7294,"Viuvo"),
  (20,"Zachary Cannon",78,"RJ","Medio",4741,"Casado"),
  (21,"Rhea Deleon",89,"CE","Superior",4645,"Viuvo"),
  (22,"Boris Yang",72,"SP","Medio",7487,"Solteiro"),
  (23,"Kai Watts",93,"SC","Medio",7380,"Casado"),
  (24,"Ori Hartman",65,"MA","Medio",8507,"Casado"),
  (25,"Jayme Downs",98,"CE","Medio",4432,"Separado"),
  (26,"Castor Roberts",91,"PB","Superior",8241,"Solteiro"),
  (27,"Kato Bass",95,"MA","Superior",4811,"Casado"),
  (28,"Gil Singleton",70,"PB","Medio",4158,"Separado"),
  (29,"Vaughan Joyner",72,"RJ","Superior",4855,"Solteiro"),
  (30,"Zenaida Myers",68,"PB","Primario",3829,"Solteiro"),
  (31,"Conan Flores",61,"SP","Medio",7590,"Separado"),
  (32,"Fritz Becker",74,"BA","Primario",6931,"Solteiro"),
  (33,"Rahim Lang",98,"RS","Medio",4008,"Separado"),
  (34,"Ahmed Rowland",78,"RJ","Superior",8378,"Viuvo"),
  (35,"Vaughan Case",86,"RJ","Primario",6351,"Solteiro"),
  (36,"Jared Wallace",69,"PE","Primario",6336,"Separado"),
  (37,"Carla Vance",97,"PB","Primario",7792,"Casado"),
  (38,"Cody Marquez",67,"MG","Primario",7120,"Solteiro"),
  (39,"Allegra Hull",68,"RJ","Primario",7835,"Casado"),
  (40,"Palmer Nolan",92,"BA","Medio",2591,"Casado"),
  (41,"Aaron Dawson",82,"SP","Medio",3278,"Casado"),
  (42,"Jelani Hopkins",68,"CE","Primario",4755,"Viuvo"),
  (43,"Nehru Chan",90,"SC","Medio",3667,"Casado"),
  (44,"Marshall Miles",72,"PB","Medio",4258,"Solteiro"),
  (45,"Dalton Wilkins",96,"CE","Primario",7799,"Casado"),
  (46,"Graham Wong",60,"RJ","Medio",4451,"Casado"),
  (47,"Drew Mckay",79,"BA","Primario",8552,"Casado"),
  (48,"Sean Wilder",64,"BA","Primario",4922,"Casado"),
  (49,"Wang Butler",61,"CE","Superior",8792,"Separado"),
  (50,"Uriel Jarvis",83,"MG","Primario",7478,"Casado"),
  (51,"Whilemina Dillon",77,"PE","Medio",4533,"Casado"),
  (52,"Hannah Yang",63,"BA","Primario",8469,"Casado"),
  (53,"Stacey Mccray",81,"MA","Primario",8416,"Separado"),
  (54,"Raphael Thomas",75,"PR","Medio",4700,"Viuvo"),
  (55,"Risa Peck",91,"MG","Superior",3324,"Separado"),
  (56,"Rashad Hinton",69,"RJ","Superior",8335,"Viuvo"),
  (57,"Brandon Kaufman",94,"PA","Primario",8539,"Casado"),
  (58,"Herman Fisher",66,"RS","Primario",8446,"Viuvo"),
  (59,"Hedwig O'donnell",62,"PB","Medio",7533,"Separado"),
  (60,"Plato Lloyd",78,"MA","Superior",7039,"Separado"),
  (61,"Evangeline Shannon",74,"PR","Medio",8935,"Separado"),
  (62,"Levi Macdonald",70,"MA","Medio",3679,"Casado"),
  (63,"Dora Knowles",62,"PE","Medio",8193,"Separado"),
  (64,"Eagan Mcbride",82,"GO","Medio",8321,"Casado"),
  (65,"Gillian Guerrero",78,"CE","Medio",3914,"Separado"),
  (66,"Chava Schroeder",89,"PA","Superior",3533,"Separado"),
  (67,"Hilda Donaldson",62,"RS","Medio",3449,"Casado"),
  (68,"Leigh Hancock",70,"BA","Superior",8604,"Solteiro"),
  (69,"Jennifer Camacho",88,"SP","Primario",5464,"Separado"),
  (70,"Hayfa Foster",66,"GO","Superior",4887,"Separado"),
  (71,"Jerome Welch",86,"RJ","Superior",8252,"Solteiro"),
  (72,"Roth Hoffman",70,"GO","Primario",4012,"Viuvo"),
  (73,"Hoyt Weber",61,"PB","Medio",5943,"Casado"),
  (74,"Martina Bowman",94,"PB","Primario",4889,"Viuvo"),
  (75,"Frances Freeman",71,"PE","Medio",4568,"Casado"),
  (76,"Scott Castro",64,"GO","Primario",7870,"Viuvo"),
  (77,"Kylie Harvey",73,"PE","Superior",8403,"Casado"),
  (78,"Lyle Odom",95,"MA","Medio",8826,"Viuvo"),
  (79,"Isadora Griffin",78,"MG","Primario",4513,"Solteiro"),
  (80,"Angelica Stevens",74,"MG","Superior",4772,"Casado"),
  (81,"Erica Gibbs",84,"CE","Primario",3480,"Separado"),
  (82,"Julian Dean",82,"MG","Primario",5250,"Casado"),
  (83,"Leandra Huffman",62,"SP","Primario",3607,"Casado"),
  (84,"Lee Soto",67,"BA","Superior",2932,"Casado"),
  (85,"Grant Boyer",68,"BA","Medio",3564,"Separado"),
  (86,"Jocelyn Wynn",82,"MG","Superior",4480,"Separado"),
  (87,"Luke Cole",63,"MG","Medio",4364,"Separado"),
  (88,"Harper Bryan",81,"SP","Primario",5435,"Casado"),
  (89,"Alexander Mclean",88,"RS","Medio",8392,"Solteiro"),
  (90,"Daryl Petty",60,"MA","Medio",2609,"Solteiro"),
  (91,"Kelsie Bowers",64,"CE","Medio",4501,"Solteiro"),
  (92,"Celeste Gates",66,"PA","Superior",3996,"Solteiro"),
  (93,"Ramona Rosario",72,"PE","Medio",2569,"Viuvo"),
  (94,"Allen Harrison",90,"SP","Medio",3832,"Casado"),
  (95,"Shelby Cash",81,"PB","Medio",5712,"Casado"),
  (96,"Aquila Michael",90,"RJ","Medio",6149,"Separado"),
  (97,"Natalie Cole",95,"PE","Superior",4169,"Separado"),
  (98,"Hamilton Hunter",79,"MG","Superior",4113,"Casado"),
  (99,"Ava Lynch",73,"GO","Primario",5362,"Solteiro"),
  (100,"Minerva Alford",85,"PE","Superior",3764,"Solteiro")
]

# %%
#POVOAMENTO DA TABELA

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Inserindo os dados na tabela criada tab_clientes
query = "INSERT INTO tab_clientes (Cliente_id, Nome, Idade, Uf, Escolaridade, Renda, Civil) VALUES ( %s, %s,%s, %s, %s,%s, %s)"

for registro in inserir_clientes:
  cursor.execute(query, registro)

conn.commit()

cursor.close()
conn.close()

# %%
#VERIFICAÇÃO DOS DADOS INSERIDOS

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Verificando os dados com uma query.
cursor.execute("SELECT * FROM tab_clientes")

# Buscando todos os dados e passando para variavel "records"
records = cursor.fetchall()

#Apresentando o que foi gravado
for record in records:
    print(record)

cursor.close()
conn.close()
# Out:
# (1, 1, 'Roth May', 82, 'RS', 'Medio', 6515, 'Separado')
# (2, 2, 'Sharon Hebert', 70, 'PE', 'Medio', 5943, 'Separado')
# (3, 3, 'Felix Cochran', 73, 'PR', 'Medio', 6264, 'Casado')
# (4, 4, 'Xanthus Schwartz', 71, 'GO', 'Medio', 4062, 'Solteiro')
# (5, 5, 'Vielka Mcintosh', 61, 'GO', 'Medio', 8316, 'Viuvo')
# (6, 6, 'Ivor Alvarez', 60, 'PR', 'Primario', 4379, 'Casado')
# (7, 7, 'Jordan Mcdonald', 78, 'SP', 'Medio', 4740, 'Casado')
# (8, 8, 'Denton Cochran', 80, 'SC', 'Medio', 4569, 'Casado')
# (9, 9, 'Caesar Hardin', 95, 'CE', 'Medio', 7315, 'Viuvo')
# (10, 10, 'Jack Dotson', 90, 'MA', 'Primario', 2985, 'Separado')
# (11, 11, 'Clark Head', 98, 'BA', 'Superior', 4370, 'Separado')
# (12, 12, 'Sage Schmidt', 61, 'CE', 'Primario', 5987, 'Separado')
# (13, 13, 'Castor Robbins', 89, 'PB', 'Superior', 6707, 'Casado')
# (14, 14, 'Drake Frank', 95, 'PB', 'Medio', 6091, 'Casado')
# (15, 15, 'Jordan Berry', 94, 'SC', 'Medio', 7184, 'Casado')
# (16, 16, 'Dawn Knight', 93, 'CE', 'Primario', 6481, 'Casado')
# (17, 17, 'Savannah Branch', 86, 'SP', 'Primario', 5874, 'Solteiro')
# (18, 18, 'Declan Cruz', 78, 'PA', 'Medio', 8040, 'Separado')
# (19, 19, 'Leilani Mcdaniel', 64, 'PA', 'Primario', 7294, 'Viuvo')
# (20, 20, 'Zachary Cannon', 78, 'RJ', 'Medio', 4741, 'Casado')
# (21, 21, 'Rhea Deleon', 89, 'CE', 'Superior', 4645, 'Viuvo')
# (22, 22, 'Boris Yang', 72, 'SP', 'Medio', 7487, 'Solteiro')
# (23, 23, 'Kai Watts', 93, 'SC', 'Medio', 7380, 'Casado')
# (24, 24, 'Ori Hartman', 65, 'MA', 'Medio', 8507, 'Casado')
# (25, 25, 'Jayme Downs', 98, 'CE', 'Medio', 4432, 'Separado')
# (26, 26, 'Castor Roberts', 91, 'PB', 'Superior', 8241, 'Solteiro')
# (27, 27, 'Kato Bass', 95, 'MA', 'Superior', 4811, 'Casado')
# (28, 28, 'Gil Singleton', 70, 'PB', 'Medio', 4158, 'Separado')
# (29, 29, 'Vaughan Joyner', 72, 'RJ', 'Superior', 4855, 'Solteiro')
# (30, 30, 'Zenaida Myers', 68, 'PB', 'Primario', 3829, 'Solteiro')
# (31, 31, 'Conan Flores', 61, 'SP', 'Medio', 7590, 'Separado')
# (32, 32, 'Fritz Becker', 74, 'BA', 'Primario', 6931, 'Solteiro')
# (33, 33, 'Rahim Lang', 98, 'RS', 'Medio', 4008, 'Separado')
# (34, 34, 'Ahmed Rowland', 78, 'RJ', 'Superior', 8378, 'Viuvo')
# (35, 35, 'Vaughan Case', 86, 'RJ', 'Primario', 6351, 'Solteiro')
# (36, 36, 'Jared Wallace', 69, 'PE', 'Primario', 6336, 'Separado')
# (37, 37, 'Carla Vance', 97, 'PB', 'Primario', 7792, 'Casado')
# (38, 38, 'Cody Marquez', 67, 'MG', 'Primario', 7120, 'Solteiro')
# (39, 39, 'Allegra Hull', 68, 'RJ', 'Primario', 7835, 'Casado')
# (40, 40, 'Palmer Nolan', 92, 'BA', 'Medio', 2591, 'Casado')
# (41, 41, 'Aaron Dawson', 82, 'SP', 'Medio', 3278, 'Casado')
# (42, 42, 'Jelani Hopkins', 68, 'CE', 'Primario', 4755, 'Viuvo')
# (43, 43, 'Nehru Chan', 90, 'SC', 'Medio', 3667, 'Casado')
# (44, 44, 'Marshall Miles', 72, 'PB', 'Medio', 4258, 'Solteiro')
# (45, 45, 'Dalton Wilkins', 96, 'CE', 'Primario', 7799, 'Casado')
# (46, 46, 'Graham Wong', 60, 'RJ', 'Medio', 4451, 'Casado')
# (47, 47, 'Drew Mckay', 79, 'BA', 'Primario', 8552, 'Casado')
# (48, 48, 'Sean Wilder', 64, 'BA', 'Primario', 4922, 'Casado')
# (49, 49, 'Wang Butler', 61, 'CE', 'Superior', 8792, 'Separado')
# (50, 50, 'Uriel Jarvis', 83, 'MG', 'Primario', 7478, 'Casado')
# (51, 51, 'Whilemina Dillon', 77, 'PE', 'Medio', 4533, 'Casado')
# (52, 52, 'Hannah Yang', 63, 'BA', 'Primario', 8469, 'Casado')
# (53, 53, 'Stacey Mccray', 81, 'MA', 'Primario', 8416, 'Separado')
# (54, 54, 'Raphael Thomas', 75, 'PR', 'Medio', 4700, 'Viuvo')
# (55, 55, 'Risa Peck', 91, 'MG', 'Superior', 3324, 'Separado')
# (56, 56, 'Rashad Hinton', 69, 'RJ', 'Superior', 8335, 'Viuvo')
# (57, 57, 'Brandon Kaufman', 94, 'PA', 'Primario', 8539, 'Casado')
# (58, 58, 'Herman Fisher', 66, 'RS', 'Primario', 8446, 'Viuvo')
# (59, 59, "Hedwig O'donnell", 62, 'PB', 'Medio', 7533, 'Separado')
# (60, 60, 'Plato Lloyd', 78, 'MA', 'Superior', 7039, 'Separado')
# (61, 61, 'Evangeline Shannon', 74, 'PR', 'Medio', 8935, 'Separado')
# (62, 62, 'Levi Macdonald', 70, 'MA', 'Medio', 3679, 'Casado')
# (63, 63, 'Dora Knowles', 62, 'PE', 'Medio', 8193, 'Separado')
# (64, 64, 'Eagan Mcbride', 82, 'GO', 'Medio', 8321, 'Casado')
# (65, 65, 'Gillian Guerrero', 78, 'CE', 'Medio', 3914, 'Separado')
# (66, 66, 'Chava Schroeder', 89, 'PA', 'Superior', 3533, 'Separado')
# (67, 67, 'Hilda Donaldson', 62, 'RS', 'Medio', 3449, 'Casado')
# (68, 68, 'Leigh Hancock', 70, 'BA', 'Superior', 8604, 'Solteiro')
# (69, 69, 'Jennifer Camacho', 88, 'SP', 'Primario', 5464, 'Separado')
# (70, 70, 'Hayfa Foster', 66, 'GO', 'Superior', 4887, 'Separado')
# (71, 71, 'Jerome Welch', 86, 'RJ', 'Superior', 8252, 'Solteiro')
# (72, 72, 'Roth Hoffman', 70, 'GO', 'Primario', 4012, 'Viuvo')
# (73, 73, 'Hoyt Weber', 61, 'PB', 'Medio', 5943, 'Casado')
# (74, 74, 'Martina Bowman', 94, 'PB', 'Primario', 4889, 'Viuvo')
# (75, 75, 'Frances Freeman', 71, 'PE', 'Medio', 4568, 'Casado')
# (76, 76, 'Scott Castro', 64, 'GO', 'Primario', 7870, 'Viuvo')
# (77, 77, 'Kylie Harvey', 73, 'PE', 'Superior', 8403, 'Casado')
# (78, 78, 'Lyle Odom', 95, 'MA', 'Medio', 8826, 'Viuvo')
# (79, 79, 'Isadora Griffin', 78, 'MG', 'Primario', 4513, 'Solteiro')
# (80, 80, 'Angelica Stevens', 74, 'MG', 'Superior', 4772, 'Casado')
# (81, 81, 'Erica Gibbs', 84, 'CE', 'Primario', 3480, 'Separado')
# (82, 82, 'Julian Dean', 82, 'MG', 'Primario', 5250, 'Casado')
# (83, 83, 'Leandra Huffman', 62, 'SP', 'Primario', 3607, 'Casado')
# (84, 84, 'Lee Soto', 67, 'BA', 'Superior', 2932, 'Casado')
# (85, 85, 'Grant Boyer', 68, 'BA', 'Medio', 3564, 'Separado')
# (86, 86, 'Jocelyn Wynn', 82, 'MG', 'Superior', 4480, 'Separado')
# (87, 87, 'Luke Cole', 63, 'MG', 'Medio', 4364, 'Separado')
# (88, 88, 'Harper Bryan', 81, 'SP', 'Primario', 5435, 'Casado')
# (89, 89, 'Alexander Mclean', 88, 'RS', 'Medio', 8392, 'Solteiro')
# (90, 90, 'Daryl Petty', 60, 'MA', 'Medio', 2609, 'Solteiro')
# (91, 91, 'Kelsie Bowers', 64, 'CE', 'Medio', 4501, 'Solteiro')
# (92, 92, 'Celeste Gates', 66, 'PA', 'Superior', 3996, 'Solteiro')
# (93, 93, 'Ramona Rosario', 72, 'PE', 'Medio', 2569, 'Viuvo')
# (94, 94, 'Allen Harrison', 90, 'SP', 'Medio', 3832, 'Casado')
# (95, 95, 'Shelby Cash', 81, 'PB', 'Medio', 5712, 'Casado')
# (96, 96, 'Aquila Michael', 90, 'RJ', 'Medio', 6149, 'Separado')
# (97, 97, 'Natalie Cole', 95, 'PE', 'Superior', 4169, 'Separado')
# (98, 98, 'Hamilton Hunter', 79, 'MG', 'Superior', 4113, 'Casado')
# (99, 99, 'Ava Lynch', 73, 'GO', 'Primario', 5362, 'Solteiro')
# (100, 100, 'Minerva Alford', 85, 'PE', 'Superior', 3764, 'Solteiro')

# %% [markdown]
# ***1.2 - Criar a tabela Remedios***

# %%
# Conectando
conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Cursor de interação
cursor = conn.cursor()

# Criar a tabela  'remedios'
cursor.execute('''
DROP TABLE IF EXISTS `tab_remedios`;

CREATE TABLE `tab_remedios` (
  `id` mediumint(8) unsigned NOT NULL auto_increment,
  `Cliente_id` mediumint,
  `Remedio` TEXT default NULL,
  PRIMARY KEY (`id`)
) AUTO_INCREMENT=1;
''')

# %%
#Dados aleatórios para popular a tabela clientes
inserir_remedios = [
    (1,"Azitromicina Cefalexina Losartana Alprazolam"),
  (2,"Azitromicina Cefalexina Losartana"),
  (3,"Azitromicina"),
  (4,"Azitromicina Cefalexina Losartana Alprazolam"),
  (5,"Azitromicina Cefalexina"),
  (6,"Azitromicina"),
  (7,"Azitromicina Cefalexina Losartana Alprazolam"),
  (8,"Azitromicina Cefalexina"),
  (9,"Azitromicina Cefalexina"),
  (10,"Azitromicina Cefalexina Losartana Alprazolam"),
  (11,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (12,"Azitromicina Cefalexina"),
  (13,"Azitromicina Cefalexina Losartana"),
  (14,"Azitromicina"),
  (15,"Azitromicina Cefalexina"),
  (16,"Azitromicina Cefalexina Losartana"),
  (17,"Azitromicina Cefalexina Losartana Alprazolam"),
  (18,"Azitromicina Cefalexina"),
  (19,"Azitromicina Cefalexina"),
  (20,"Azitromicina"),
  (21,"Azitromicina Cefalexina"),
  (22,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (23,"Azitromicina Cefalexina Losartana Alprazolam"),
  (24,"Azitromicina Cefalexina"),
  (25,"Azitromicina Cefalexina"),
  (26,"Azitromicina Cefalexina"),
  (27,"Azitromicina Cefalexina"),
  (28,"Azitromicina Cefalexina Losartana Alprazolam"),
  (29,"Azitromicina Cefalexina"),
  (30,"Azitromicina Cefalexina Losartana"),
  (31,"Azitromicina Cefalexina Losartana Alprazolam"),
  (32,"Azitromicina Cefalexina Losartana"),
  (33,"Azitromicina Cefalexina Losartana Alprazolam"),
  (34,"Azitromicina Cefalexina"),
  (35,"Azitromicina Cefalexina Losartana Alprazolam"),
  (36,"Azitromicina Cefalexina Losartana Alprazolam"),
  (37,"Azitromicina"),
  (38,"Azitromicina Cefalexina Losartana"),
  (39,"Azitromicina Cefalexina"),
  (40,"Azitromicina"),
  (41,"Azitromicina Cefalexina"),
  (42,"Azitromicina Cefalexina Losartana Alprazolam"),
  (43,"Azitromicina Cefalexina Losartana"),
  (44,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (45,"Azitromicina"),
  (46,"Azitromicina Cefalexina Losartana"),
  (47,"Azitromicina"),
  (48,"Azitromicina Cefalexina Losartana Alprazolam"),
  (49,"Azitromicina Cefalexina"),
  (50,"Azitromicina"),
  (51,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (52,"Azitromicina Cefalexina Losartana Alprazolam"),
  (53,"Azitromicina Cefalexina"),
  (54,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (55,"Azitromicina"),
  (56,"Azitromicina Cefalexina Losartana"),
  (57,"Azitromicina Cefalexina Losartana Alprazolam"),
  (58,"Azitromicina Cefalexina Losartana Alprazolam"),
  (59,"Azitromicina Cefalexina"),
  (60,"Azitromicina Cefalexina Losartana Alprazolam"),
  (61,"Azitromicina Cefalexina Losartana Alprazolam"),
  (62,"Azitromicina Cefalexina Losartana Alprazolam"),
  (63,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (64,"Azitromicina Cefalexina"),
  (65,"Azitromicina Cefalexina Losartana"),
  (66,"Azitromicina Cefalexina"),
  (67,"Azitromicina Cefalexina"),
  (68,"Azitromicina Cefalexina Losartana"),
  (69,"Azitromicina"),
  (70,"Azitromicina Cefalexina Losartana"),
  (71,"Azitromicina"),
  (72,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (73,"Azitromicina Cefalexina Losartana Alprazolam"),
  (74,"Azitromicina Cefalexina Losartana Alprazolam"),
  (75,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (76,"Azitromicina Cefalexina"),
  (77,"Azitromicina Cefalexina Losartana"),
  (78,"Azitromicina Cefalexina"),
  (79,"Azitromicina Cefalexina"),
  (80,"Azitromicina Cefalexina Losartana"),
  (81,"Azitromicina Cefalexina"),
  (82,"Azitromicina Cefalexina Losartana Alprazolam"),
  (83,"Azitromicina Cefalexina Losartana Alprazolam"),
  (84,"Azitromicina Cefalexina Losartana Alprazolam"),
  (85,"Azitromicina Cefalexina Losartana Alprazolam"),
  (86,"Azitromicina Cefalexina"),
  (87,"Azitromicina Cefalexina Losartana Alprazolam"),
  (88,"Azitromicina Cefalexina"),
  (89,"Azitromicina Cefalexina Losartana Alprazolam"),
  (90,"Azitromicina Cefalexina Losartana Alprazolam"),
  (91,"Azitromicina Cefalexina Losartana"),
  (92,"Azitromicina Cefalexina"),
  (93,"Azitromicina Cefalexina"),
  (94,"Azitromicina Cefalexina Losartana"),
  (95,"Azitromicina Cefalexina Losartana Alprazolam"),
  (96,"Azitromicina Cefalexina Losartana"),
  (97,"Azitromicina"),
  (98,"Azitromicina Cefalexina Losartana Alprazolam Sinvastatina"),
  (99,"Azitromicina Cefalexina Losartana Alprazolam"),
  (100,"Azitromicina Cefalexina Losartana Alprazolam")
]

# %%
#POVOAMENTO DA TABELA

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

 #Inserindo os dados na tabela criada tab_sintomas
query = "INSERT INTO tab_remedios (Cliente_id, Remedio) VALUES ( %s,%s)"

for registro in inserir_remedios:
  cursor.execute(query, registro)

conn.commit()

cursor.close()
conn.close()

# %%
#VERIFICAÇÃO DOS DADOS INSERIDOS

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Verificando os dados com uma query.
cursor.execute("SELECT * FROM tab_remedios")

# Buscando todos os dados e passando para variavel "records"
records = cursor.fetchall()

#Apresentando o que foi gravado
for record in records:
    print(record)

cursor.close()
conn.close()
# Out:
# (1, 1, 'Azitromicina Cefalexina Losartana Alprazolam')
# (2, 2, 'Azitromicina Cefalexina Losartana')
# (3, 3, 'Azitromicina')
# (4, 4, 'Azitromicina Cefalexina Losartana Alprazolam')
# (5, 5, 'Azitromicina Cefalexina')
# (6, 6, 'Azitromicina')
# (7, 7, 'Azitromicina Cefalexina Losartana Alprazolam')
# (8, 8, 'Azitromicina Cefalexina')
# (9, 9, 'Azitromicina Cefalexina')
# (10, 10, 'Azitromicina Cefalexina Losartana Alprazolam')
# (11, 11, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (12, 12, 'Azitromicina Cefalexina')
# (13, 13, 'Azitromicina Cefalexina Losartana')
# (14, 14, 'Azitromicina')
# (15, 15, 'Azitromicina Cefalexina')
# (16, 16, 'Azitromicina Cefalexina Losartana')
# (17, 17, 'Azitromicina Cefalexina Losartana Alprazolam')
# (18, 18, 'Azitromicina Cefalexina')
# (19, 19, 'Azitromicina Cefalexina')
# (20, 20, 'Azitromicina')
# (21, 21, 'Azitromicina Cefalexina')
# (22, 22, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (23, 23, 'Azitromicina Cefalexina Losartana Alprazolam')
# (24, 24, 'Azitromicina Cefalexina')
# (25, 25, 'Azitromicina Cefalexina')
# (26, 26, 'Azitromicina Cefalexina')
# (27, 27, 'Azitromicina Cefalexina')
# (28, 28, 'Azitromicina Cefalexina Losartana Alprazolam')
# (29, 29, 'Azitromicina Cefalexina')
# (30, 30, 'Azitromicina Cefalexina Losartana')
# (31, 31, 'Azitromicina Cefalexina Losartana Alprazolam')
# (32, 32, 'Azitromicina Cefalexina Losartana')
# (33, 33, 'Azitromicina Cefalexina Losartana Alprazolam')
# (34, 34, 'Azitromicina Cefalexina')
# (35, 35, 'Azitromicina Cefalexina Losartana Alprazolam')
# (36, 36, 'Azitromicina Cefalexina Losartana Alprazolam')
# (37, 37, 'Azitromicina')
# (38, 38, 'Azitromicina Cefalexina Losartana')
# (39, 39, 'Azitromicina Cefalexina')
# (40, 40, 'Azitromicina')
# (41, 41, 'Azitromicina Cefalexina')
# (42, 42, 'Azitromicina Cefalexina Losartana Alprazolam')
# (43, 43, 'Azitromicina Cefalexina Losartana')
# (44, 44, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (45, 45, 'Azitromicina')
# (46, 46, 'Azitromicina Cefalexina Losartana')
# (47, 47, 'Azitromicina')
# (48, 48, 'Azitromicina Cefalexina Losartana Alprazolam')
# (49, 49, 'Azitromicina Cefalexina')
# (50, 50, 'Azitromicina')
# (51, 51, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (52, 52, 'Azitromicina Cefalexina Losartana Alprazolam')
# (53, 53, 'Azitromicina Cefalexina')
# (54, 54, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (55, 55, 'Azitromicina')
# (56, 56, 'Azitromicina Cefalexina Losartana')
# (57, 57, 'Azitromicina Cefalexina Losartana Alprazolam')
# (58, 58, 'Azitromicina Cefalexina Losartana Alprazolam')
# (59, 59, 'Azitromicina Cefalexina')
# (60, 60, 'Azitromicina Cefalexina Losartana Alprazolam')
# (61, 61, 'Azitromicina Cefalexina Losartana Alprazolam')
# (62, 62, 'Azitromicina Cefalexina Losartana Alprazolam')
# (63, 63, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (64, 64, 'Azitromicina Cefalexina')
# (65, 65, 'Azitromicina Cefalexina Losartana')
# (66, 66, 'Azitromicina Cefalexina')
# (67, 67, 'Azitromicina Cefalexina')
# (68, 68, 'Azitromicina Cefalexina Losartana')
# (69, 69, 'Azitromicina')
# (70, 70, 'Azitromicina Cefalexina Losartana')
# (71, 71, 'Azitromicina')
# (72, 72, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (73, 73, 'Azitromicina Cefalexina Losartana Alprazolam')
# (74, 74, 'Azitromicina Cefalexina Losartana Alprazolam')
# (75, 75, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (76, 76, 'Azitromicina Cefalexina')
# (77, 77, 'Azitromicina Cefalexina Losartana')
# (78, 78, 'Azitromicina Cefalexina')
# (79, 79, 'Azitromicina Cefalexina')
# (80, 80, 'Azitromicina Cefalexina Losartana')
# (81, 81, 'Azitromicina Cefalexina')
# (82, 82, 'Azitromicina Cefalexina Losartana Alprazolam')
# (83, 83, 'Azitromicina Cefalexina Losartana Alprazolam')
# (84, 84, 'Azitromicina Cefalexina Losartana Alprazolam')
# (85, 85, 'Azitromicina Cefalexina Losartana Alprazolam')
# (86, 86, 'Azitromicina Cefalexina')
# (87, 87, 'Azitromicina Cefalexina Losartana Alprazolam')
# (88, 88, 'Azitromicina Cefalexina')
# (89, 89, 'Azitromicina Cefalexina Losartana Alprazolam')
# (90, 90, 'Azitromicina Cefalexina Losartana Alprazolam')
# (91, 91, 'Azitromicina Cefalexina Losartana')
# (92, 92, 'Azitromicina Cefalexina')
# (93, 93, 'Azitromicina Cefalexina')
# (94, 94, 'Azitromicina Cefalexina Losartana')
# (95, 95, 'Azitromicina Cefalexina Losartana Alprazolam')
# (96, 96, 'Azitromicina Cefalexina Losartana')
# (97, 97, 'Azitromicina')
# (98, 98, 'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina')
# (99, 99, 'Azitromicina Cefalexina Losartana Alprazolam')
# (100, 100, 'Azitromicina Cefalexina Losartana Alprazolam')

# %% [markdown]
# ***1.3 - Criar a tabela sintomas***

# %%
# Conectando
conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Cursor de interação
cursor = conn.cursor()

# Criar a tabela  'Sintomas'
cursor.execute('''
DROP TABLE IF EXISTS `tab_sintomas`;

CREATE TABLE `tab_sintomas` (
  `id` mediumint(8) unsigned NOT NULL auto_increment,
  `Sintoma` TEXT default NULL,
  `Data` varchar(255),
  `Cliente_id` mediumint default NULL,
  PRIMARY KEY (`id`)
) AUTO_INCREMENT=1;
''')

# %%
#Dados aleatórios para popular a tabela sintomas
inserir_sintomas = [
    ("Normal","2022-09-07",80),
  ("Lapsos_de_memoria","2023-03-29",5),
  ("Incontinencia_urinaria","2023-05-15",47),
  ("Insonia","2022-11-29",92),
  ("Agressividade","2022-10-17",85),
  ("Insonia","2021-07-10",28),
  ("Lapsos_de_memoria","2022-07-26",37),
  ("Agressividade","2022-03-21",57),
  ("Lapsos_de_memoria","2023-01-01",45),
  ("Lapsos_de_memoria","2022-08-12",36),
  ("Agressividade","2022-04-24",8),
  ("Vomito","2023-03-08",94),
  ("Agressividade","2021-05-27",58),
  ("Lapsos_de_memoria","2021-12-02",26),
  ("Lapsos_de_memoria","2021-12-07",43),
  ("Lapsos_de_memoria","2021-11-23",34),
  ("Agressividade","2022-10-02",61),
  ("Agressividade","2021-06-17",34),
  ("Quedas_de_pressao","2023-03-18",45),
  ("Agressividade","2023-09-30",96),
  ("Insonia","2021-01-15",34),
  ("Lapsos_de_memoria","2022-11-08",80),
  ("Insonia","2021-12-17",80),
  ("Vomito","2021-08-07",42),
  ("Incontinencia_urinaria","2022-03-15",96),
  ("Vomito","2021-01-07",48),
  ("Vomito","2022-10-08",49),
  ("Vomito","2022-10-25",36),
  ("Lapsos_de_memoria","2022-08-24",95),
  ("Insonia","2022-02-19",54),
  ("Insonia","2021-01-17",41),
  ("Quedas_de_pressao","2021-01-18",2),
  ("Lapsos_de_memoria","2022-07-04",6),
  ("Incontinencia_urinaria","2022-12-06",32),
  ("Agressividade","2022-12-06",59),
  ("Insonia","2022-07-23",71),
  ("Incontinencia_urinaria","2022-06-17",80),
  ("Insonia","2021-02-10",45),
  ("Lapsos_de_memoria","2021-05-13",90),
  ("Agressividade","2022-09-09",58),
  ("Agressividade","2021-08-06",54),
  ("Lapsos_de_memoria","2023-08-17",98),
  ("Incontinencia_urinaria","2022-11-23",42),
  ("Quedas_de_pressao","2023-01-13",2),
  ("Lapsos_de_memoria","2023-04-02",28),
  ("Lapsos_de_memoria","2021-06-04",86),
  ("Normal","2023-08-30",51),
  ("Lapsos_de_memoria","2022-05-15",92),
  ("Insonia","2022-08-11",88),
  ("Insonia","2023-08-14",88),
  ("Vomito","2023-03-29",2),
  ("Agressividade","2023-09-06",30),
  ("Agressividade","2023-07-26",52),
  ("Insonia","2023-07-04",6),
  ("Vomito","2021-07-07",21),
  ("Insonia","2023-10-12",24),
  ("Agressividade","2022-08-05",61),
  ("Incontinencia_urinaria","2021-01-19",32),
  ("Insonia","2022-09-07",60),
  ("Lapsos_de_memoria","2022-01-07",67),
  ("Quedas_de_pressao","2023-05-29",33),
  ("Insonia","2022-02-12",20),
  ("Lapsos_de_memoria","2021-09-25",18),
  ("Quedas_de_pressao","2021-08-01",4),
  ("Quedas_de_pressao","2022-11-29",89),
  ("Normal","2021-08-31",67),
  ("Normal","2023-03-15",18),
  ("Normal","2021-08-22",83),
  ("Insonia","2021-12-29",6),
  ("Quedas_de_pressao","2022-01-03",32),
  ("Agressividade","2022-03-15",39),
  ("Incontinencia_urinaria","2022-04-11",8),
  ("Agressividade","2022-07-24",81),
  ("Lapsos_de_memoria","2022-07-16",53),
  ("Incontinencia_urinaria","2023-03-15",15),
  ("Agressividade","2023-03-07",66),
  ("Agressividade","2021-06-14",55),
  ("Insonia","2023-03-01",33),
  ("Incontinencia_urinaria","2023-02-04",1),
  ("Vomito","2022-08-03",10),
  ("Vomito","2022-06-19",7),
  ("Normal","2023-10-28",65),
  ("Insonia","2023-02-27",17),
  ("Agressividade","2021-07-30",45),
  ("Incontinencia_urinaria","2022-01-18",45),
  ("Agressividade","2021-03-09",53),
  ("Vomito","2021-05-04",44),
  ("Incontinencia_urinaria","2021-12-12",70),
  ("Vomito","2021-04-05",54),
  ("Agressividade","2022-07-23",82),
  ("Lapsos_de_memoria","2023-04-15",6),
  ("Quedas_de_pressao","2023-02-17",53),
  ("Agressividade","2021-05-04",46),
  ("Lapsos_de_memoria","2022-05-10",91),
  ("Vomito","2023-05-07",71),
  ("Lapsos_de_memoria","2022-10-22",47),
  ("Insonia","2022-01-04",53),
  ("Vomito","2023-04-10",49),
  ("Lapsos_de_memoria","2023-07-09",50),
  ("Lapsos_de_memoria","2022-09-09",92)
]

# %%
#POVOAMENTO DA TABELA

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

 #Inserindo os dados na tabela criada tab_sintomas
query = "INSERT INTO tab_sintomas (Sintoma, Data, Cliente_id) VALUES ( %s,%s, %s)"

for registro in inserir_sintomas:
  cursor.execute(query, registro)


# Commit the changes
conn.commit()

cursor.close()
conn.close()

# %%
#VERIFICAÇÃO DOS DADOS INSERIDOS

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')
cursor = conn.cursor()

# Verificando os dados com uma query.
cursor.execute("SELECT * FROM tab_sintomas")

# Buscando todos os dados e passando para variavel "records"
records = cursor.fetchall()

#Apresentando o que foi gravado
for record in records:
    print(record)

cursor.close()
conn.close()
# Out:
# (1, 'Normal', '2022-09-07', 80)
# (2, 'Lapsos_de_memoria', '2023-03-29', 5)
# (3, 'Incontinencia_urinaria', '2023-05-15', 47)
# (4, 'Insonia', '2022-11-29', 92)
# (5, 'Agressividade', '2022-10-17', 85)
# (6, 'Insonia', '2021-07-10', 28)
# (7, 'Lapsos_de_memoria', '2022-07-26', 37)
# (8, 'Agressividade', '2022-03-21', 57)
# (9, 'Lapsos_de_memoria', '2023-01-01', 45)
# (10, 'Lapsos_de_memoria', '2022-08-12', 36)
# (11, 'Agressividade', '2022-04-24', 8)
# (12, 'Vomito', '2023-03-08', 94)
# (13, 'Agressividade', '2021-05-27', 58)
# (14, 'Lapsos_de_memoria', '2021-12-02', 26)
# (15, 'Lapsos_de_memoria', '2021-12-07', 43)
# (16, 'Lapsos_de_memoria', '2021-11-23', 34)
# (17, 'Agressividade', '2022-10-02', 61)
# (18, 'Agressividade', '2021-06-17', 34)
# (19, 'Quedas_de_pressao', '2023-03-18', 45)
# (20, 'Agressividade', '2023-09-30', 96)
# (21, 'Insonia', '2021-01-15', 34)
# (22, 'Lapsos_de_memoria', '2022-11-08', 80)
# (23, 'Insonia', '2021-12-17', 80)
# (24, 'Vomito', '2021-08-07', 42)
# (25, 'Incontinencia_urinaria', '2022-03-15', 96)
# (26, 'Vomito', '2021-01-07', 48)
# (27, 'Vomito', '2022-10-08', 49)
# (28, 'Vomito', '2022-10-25', 36)
# (29, 'Lapsos_de_memoria', '2022-08-24', 95)
# (30, 'Insonia', '2022-02-19', 54)
# (31, 'Insonia', '2021-01-17', 41)
# (32, 'Quedas_de_pressao', '2021-01-18', 2)
# (33, 'Lapsos_de_memoria', '2022-07-04', 6)
# (34, 'Incontinencia_urinaria', '2022-12-06', 32)
# (35, 'Agressividade', '2022-12-06', 59)
# (36, 'Insonia', '2022-07-23', 71)
# (37, 'Incontinencia_urinaria', '2022-06-17', 80)
# (38, 'Insonia', '2021-02-10', 45)
# (39, 'Lapsos_de_memoria', '2021-05-13', 90)
# (40, 'Agressividade', '2022-09-09', 58)
# (41, 'Agressividade', '2021-08-06', 54)
# (42, 'Lapsos_de_memoria', '2023-08-17', 98)
# (43, 'Incontinencia_urinaria', '2022-11-23', 42)
# (44, 'Quedas_de_pressao', '2023-01-13', 2)
# (45, 'Lapsos_de_memoria', '2023-04-02', 28)
# (46, 'Lapsos_de_memoria', '2021-06-04', 86)
# (47, 'Normal', '2023-08-30', 51)
# (48, 'Lapsos_de_memoria', '2022-05-15', 92)
# (49, 'Insonia', '2022-08-11', 88)
# (50, 'Insonia', '2023-08-14', 88)
# (51, 'Vomito', '2023-03-29', 2)
# (52, 'Agressividade', '2023-09-06', 30)
# (53, 'Agressividade', '2023-07-26', 52)
# (54, 'Insonia', '2023-07-04', 6)
# (55, 'Vomito', '2021-07-07', 21)
# (56, 'Insonia', '2023-10-12', 24)
# (57, 'Agressividade', '2022-08-05', 61)
# (58, 'Incontinencia_urinaria', '2021-01-19', 32)
# (59, 'Insonia', '2022-09-07', 60)
# (60, 'Lapsos_de_memoria', '2022-01-07', 67)
# (61, 'Quedas_de_pressao', '2023-05-29', 33)
# (62, 'Insonia', '2022-02-12', 20)
# (63, 'Lapsos_de_memoria', '2021-09-25', 18)
# (64, 'Quedas_de_pressao', '2021-08-01', 4)
# (65, 'Quedas_de_pressao', '2022-11-29', 89)
# (66, 'Normal', '2021-08-31', 67)
# (67, 'Normal', '2023-03-15', 18)
# (68, 'Normal', '2021-08-22', 83)
# (69, 'Insonia', '2021-12-29', 6)
# (70, 'Quedas_de_pressao', '2022-01-03', 32)
# (71, 'Agressividade', '2022-03-15', 39)
# (72, 'Incontinencia_urinaria', '2022-04-11', 8)
# (73, 'Agressividade', '2022-07-24', 81)
# (74, 'Lapsos_de_memoria', '2022-07-16', 53)
# (75, 'Incontinencia_urinaria', '2023-03-15', 15)
# (76, 'Agressividade', '2023-03-07', 66)
# (77, 'Agressividade', '2021-06-14', 55)
# (78, 'Insonia', '2023-03-01', 33)
# (79, 'Incontinencia_urinaria', '2023-02-04', 1)
# (80, 'Vomito', '2022-08-03', 10)
# (81, 'Vomito', '2022-06-19', 7)
# (82, 'Normal', '2023-10-28', 65)
# (83, 'Insonia', '2023-02-27', 17)
# (84, 'Agressividade', '2021-07-30', 45)
# (85, 'Incontinencia_urinaria', '2022-01-18', 45)
# (86, 'Agressividade', '2021-03-09', 53)
# (87, 'Vomito', '2021-05-04', 44)
# (88, 'Incontinencia_urinaria', '2021-12-12', 70)
# (89, 'Vomito', '2021-04-05', 54)
# (90, 'Agressividade', '2022-07-23', 82)
# (91, 'Lapsos_de_memoria', '2023-04-15', 6)
# (92, 'Quedas_de_pressao', '2023-02-17', 53)
# (93, 'Agressividade', '2021-05-04', 46)
# (94, 'Lapsos_de_memoria', '2022-05-10', 91)
# (95, 'Vomito', '2023-05-07', 71)
# (96, 'Lapsos_de_memoria', '2022-10-22', 47)
# (97, 'Insonia', '2022-01-04', 53)
# (98, 'Vomito', '2023-04-10', 49)
# (99, 'Lapsos_de_memoria', '2023-07-09', 50)
# (100, 'Lapsos_de_memoria', '2022-09-09', 92)

# %% [markdown]
# # **2 - Transformar o Banco de dados em CSV**

# %%
#Importando bibliotecas

from mysql.connector import Error
import pandas as pd

# %% [markdown]
# ***Conexão com o Banco de Dados Mysql***

# %%
#Função para criar consultas

def executa_query(conn, query):
    cursor = conn.cursor()
    try:
        cursor.execute(query)
        print("Consulta feita com sucesso")
    except Error as err:
        print(f"Erro: '{err}'")

#Função para ler dados
def ler_query(conn, query):
    cursor = conn.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as err:
        print(f"Error: '{err}'")

# %% [markdown]
# ***2.1 - Importação e tratamento da tabela clientes***

# %%
tab_clientes = """
SELECT *
FROM tab_clientes;
"""

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')

results = ler_query(conn, tab_clientes)

#Tranformando a query em dataframe
df_clientes = pd.DataFrame(results)
df_clientes.head(10)
# Out:
#     0   1                 2   3   4         5     6         7
# 0   1   1          Roth May  82  RS     Medio  6515  Separado
# 1   2   2     Sharon Hebert  70  PE     Medio  5943  Separado
# 2   3   3     Felix Cochran  73  PR     Medio  6264    Casado
# 3   4   4  Xanthus Schwartz  71  GO     Medio  4062  Solteiro
# 4   5   5   Vielka Mcintosh  61  GO     Medio  8316     Viuvo
# 5   6   6      Ivor Alvarez  60  PR  Primario  4379    Casado
# 6   7   7   Jordan Mcdonald  78  SP     Medio  4740    Casado
# 7   8   8    Denton Cochran  80  SC     Medio  4569    Casado
# 8   9   9     Caesar Hardin  95  CE     Medio  7315     Viuvo
# 9  10  10       Jack Dotson  90  MA  Primario  2985  Separado

# %%
#Alterando o nome das colunas
df_clientes.columns =['id','Cliente_id','Nome','idade','Uf','Escolaridade','Renda','Civil']

#Verificando
df_clientes
# Out:
#      id  Cliente_id              Nome  idade  Uf Escolaridade  Renda     Civil
# 0     1           1          Roth May     82  RS        Medio   6515  Separado
# 1     2           2     Sharon Hebert     70  PE        Medio   5943  Separado
# 2     3           3     Felix Cochran     73  PR        Medio   6264    Casado
# 3     4           4  Xanthus Schwartz     71  GO        Medio   4062  Solteiro
# 4     5           5   Vielka Mcintosh     61  GO        Medio   8316     Viuvo
# ..  ...         ...               ...    ...  ..          ...    ...       ...
# 95   96          96    Aquila Michael     90  RJ        Medio   6149  Separado
# 96   97          97      Natalie Cole     95  PE     Superior   4169  Separado
# 97   98          98   Hamilton Hunter     79  MG     Superior   4113    Casado
# 98   99          99         Ava Lynch     73  GO     Primario   5362  Solteiro
# 99  100         100    Minerva Alford     85  PE     Superior   3764  Solteiro
#
# [100 rows x 8 columns]

# %% [markdown]
# ***2.2 - Importação e tratamento da tabela Remedios***

# %%
tab_remedios = """
SELECT *
FROM tab_remedios;
"""

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')

results = ler_query(conn, tab_remedios)

#Tranformando a query em dataframe
df_remedios = pd.DataFrame(results)
df_remedios.head(10)
# Out:
#     0   1                                             2
# 0   1   1  Azitromicina Cefalexina Losartana Alprazolam
# 1   2   2             Azitromicina Cefalexina Losartana
# 2   3   3                                  Azitromicina
# 3   4   4  Azitromicina Cefalexina Losartana Alprazolam
# 4   5   5                       Azitromicina Cefalexina
# 5   6   6                                  Azitromicina
# 6   7   7  Azitromicina Cefalexina Losartana Alprazolam
# 7   8   8                       Azitromicina Cefalexina
# 8   9   9                       Azitromicina Cefalexina
# 9  10  10  Azitromicina Cefalexina Losartana Alprazolam

# %%
#Alterando as colunas
df_remedios.columns =['id','Cliente_id','Remedios']

# %%
df_remedios.head(10)
# Out:
#    id  Cliente_id                                      Remedios
# 0   1           1  Azitromicina Cefalexina Losartana Alprazolam
# 1   2           2             Azitromicina Cefalexina Losartana
# 2   3           3                                  Azitromicina
# 3   4           4  Azitromicina Cefalexina Losartana Alprazolam
# 4   5           5                       Azitromicina Cefalexina
# 5   6           6                                  Azitromicina
# 6   7           7  Azitromicina Cefalexina Losartana Alprazolam
# 7   8           8                       Azitromicina Cefalexina
# 8   9           9                       Azitromicina Cefalexina
# 9  10          10  Azitromicina Cefalexina Losartana Alprazolam

# %%
df_remedios.convert_dtypes()
# Out:
#      id  Cliente_id                                           Remedios
# 0     1           1       Azitromicina Cefalexina Losartana Alprazolam
# 1     2           2                  Azitromicina Cefalexina Losartana
# 2     3           3                                       Azitromicina
# 3     4           4       Azitromicina Cefalexina Losartana Alprazolam
# 4     5           5                            Azitromicina Cefalexina
# ..  ...         ...                                                ...
# 95   96          96                  Azitromicina Cefalexina Losartana
# 96   97          97                                       Azitromicina
# 97   98          98  Azitromicina Cefalexina Losartana Alprazolam S...
# 98   99          99       Azitromicina Cefalexina Losartana Alprazolam
# 99  100         100       Azitromicina Cefalexina Losartana Alprazolam
#
# [100 rows x 3 columns]

# %%
#Coluna remedios para Texto
df_remedios['Remedios'] = df_remedios['Remedios'].astype(str)

# %%
df_remedios.head(10)
# Out:
#    id  Cliente_id                                      Remedios
# 0   1           1  Azitromicina Cefalexina Losartana Alprazolam
# 1   2           2             Azitromicina Cefalexina Losartana
# 2   3           3                                  Azitromicina
# 3   4           4  Azitromicina Cefalexina Losartana Alprazolam
# 4   5           5                       Azitromicina Cefalexina
# 5   6           6                                  Azitromicina
# 6   7           7  Azitromicina Cefalexina Losartana Alprazolam
# 7   8           8                       Azitromicina Cefalexina
# 8   9           9                       Azitromicina Cefalexina
# 9  10          10  Azitromicina Cefalexina Losartana Alprazolam

# %% [markdown]
# ***2.3 - Importando e tratando a tabela Sintomas***

# %%
tab_sintomas = """
SELECT * FROM tab_sintomas;
"""

conn = mysql.connector.connect(user='root', password='root', host='localhost', database='Base_dados')

results = ler_query(conn, tab_sintomas)

#Tranformando a query em dataframe
df_sintomas = pd.DataFrame(results)
df_sintomas.head(10)
# Out:
#     0                       1           2   3
# 0   1                  Normal  2022-09-07  80
# 1   2       Lapsos_de_memoria  2023-03-29   5
# 2   3  Incontinencia_urinaria  2023-05-15  47
# 3   4                 Insonia  2022-11-29  92
# 4   5           Agressividade  2022-10-17  85
# 5   6                 Insonia  2021-07-10  28
# 6   7       Lapsos_de_memoria  2022-07-26  37
# 7   8           Agressividade  2022-03-21  57
# 8   9       Lapsos_de_memoria  2023-01-01  45
# 9  10       Lapsos_de_memoria  2022-08-12  36

# %%
#Alterando as colunas
df_sintomas.columns =['id','Sintomas','Data','Cliente_id']

# %%
df_sintomas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   Sintomas    100 non-null    object
#  2   Data        100 non-null    object
#  3   Cliente_id  100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ KB

# %%
df_sintomas.convert_dtypes()
# Out:
#      id                Sintomas        Data  Cliente_id
# 0     1                  Normal  2022-09-07          80
# 1     2       Lapsos_de_memoria  2023-03-29           5
# 2     3  Incontinencia_urinaria  2023-05-15          47
# 3     4                 Insonia  2022-11-29          92
# 4     5           Agressividade  2022-10-17          85
# ..  ...                     ...         ...         ...
# 95   96       Lapsos_de_memoria  2022-10-22          47
# 96   97                 Insonia  2022-01-04          53
# 97   98                  Vomito  2023-04-10          49
# 98   99       Lapsos_de_memoria  2023-07-09          50
# 99  100       Lapsos_de_memoria  2022-09-09          92
#
# [100 rows x 4 columns]

# %%
df_sintomas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   Sintomas    100 non-null    object
#  2   Data        100 non-null    object
#  3   Cliente_id  100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ KB

# %% [markdown]
# # **2.4 - União dos Dataframes**

# %% [markdown]
# ***2.4.1 - Remedios e Clientes***

# %%
df_a = pd.merge(df_remedios, df_clientes, on=['id'], how='inner')

# %%
df_a.head()
# Out:
#    id                                      Remedios              Nome  idade  \
# 0   1  Azitromicina Cefalexina Losartana Alprazolam          Roth May     82
# 1   2             Azitromicina Cefalexina Losartana     Sharon Hebert     70
# 2   3                                  Azitromicina     Felix Cochran     73
# 3   4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz     71
# 4   5                       Azitromicina Cefalexina   Vielka Mcintosh     61
#
#    Uf Escolaridade  Renda     Civil
# 0  RS        Medio   6515  Separado
# 1  PE        Medio   5943  Separado
# 2  PR        Medio   6264    Casado
# 3  GO        Medio   4062  Solteiro
# 4  GO        Medio   8316     Viuvo

# %%
df_a = df_a.drop(columns=['Cliente_id_x','Cliente_id_y'])

# %%
df_a.head(10)
# Out:
#    id                                      Remedios              Nome  idade  \
# 0   1  Azitromicina Cefalexina Losartana Alprazolam          Roth May     82
# 1   2             Azitromicina Cefalexina Losartana     Sharon Hebert     70
# 2   3                                  Azitromicina     Felix Cochran     73
# 3   4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz     71
# 4   5                       Azitromicina Cefalexina   Vielka Mcintosh     61
# 5   6                                  Azitromicina      Ivor Alvarez     60
# 6   7  Azitromicina Cefalexina Losartana Alprazolam   Jordan Mcdonald     78
# 7   8                       Azitromicina Cefalexina    Denton Cochran     80
# 8   9                       Azitromicina Cefalexina     Caesar Hardin     95
# 9  10  Azitromicina Cefalexina Losartana Alprazolam       Jack Dotson     90
#
#    Uf Escolaridade  Renda     Civil
# 0  RS        Medio   6515  Separado
# 1  PE        Medio   5943  Separado
# 2  PR        Medio   6264    Casado
# 3  GO        Medio   4062  Solteiro
# 4  GO        Medio   8316     Viuvo
# 5  PR     Primario   4379    Casado
# 6  SP        Medio   4740    Casado
# 7  SC        Medio   4569    Casado
# 8  CE        Medio   7315     Viuvo
# 9  MA     Primario   2985  Separado

# %% [markdown]
# ***2.4.2 - Unindo os dataframes clientes, remedios e sintomas***

# %%
df_b = pd.merge(df_a, df_sintomas, on=['id'], how='inner')

# %%
#Alterando algumas colunas
df_b = df_b.drop(columns=['Cliente_id'])
df_b = df_b.rename(columns={'id':'Cliente_id'})

# %%
df_b
# Out:
#     Cliente_id                                           Remedios  \
# 0            1       Azitromicina Cefalexina Losartana Alprazolam
# 1            2                  Azitromicina Cefalexina Losartana
# 2            3                                       Azitromicina
# 3            4       Azitromicina Cefalexina Losartana Alprazolam
# 4            5                            Azitromicina Cefalexina
# ..         ...                                                ...
# 95          96                  Azitromicina Cefalexina Losartana
# 96          97                                       Azitromicina
# 97          98  Azitromicina Cefalexina Losartana Alprazolam S...
# 98          99       Azitromicina Cefalexina Losartana Alprazolam
# 99         100       Azitromicina Cefalexina Losartana Alprazolam
#
#                 Nome  idade  Uf Escolaridade  Renda     Civil  \
# 0           Roth May     82  RS        Medio   6515  Separado
# 1      Sharon Hebert     70  PE        Medio   5943  Separado
# 2      Felix Cochran     73  PR        Medio   6264    Casado
# 3   Xanthus Schwartz     71  GO        Medio   4062  Solteiro
# 4    Vielka Mcintosh     61  GO        Medio   8316     Viuvo
# ..               ...    ...  ..          ...    ...       ...
# 95    Aquila Michael     90  RJ        Medio   6149  Separado
# 96      Natalie Cole     95  PE     Superior   4169  Separado
# 97   Hamilton Hunter     79  MG     Superior   4113    Casado
# 98         Ava Lynch     73  GO     Primario   5362  Solteiro
# 99    Minerva Alford     85  PE     Superior   3764  Solteiro
#
#                   Sintomas        Data
# 0                   Normal  2022-09-07
# 1        Lapsos_de_memoria  2023-03-29
# 2   Incontinencia_urinaria  2023-05-15
# 3                  Insonia  2022-11-29
# 4            Agressividade  2022-10-17
# ..                     ...         ...
# 95       Lapsos_de_memoria  2022-10-22
# 96                 Insonia  2022-01-04
# 97                  Vomito  2023-04-10
# 98       Lapsos_de_memoria  2023-07-09
# 99       Lapsos_de_memoria  2022-09-09
#
# [100 rows x 10 columns]

# %% [markdown]
# # **2.5 - Criando a Base de dados**

# %%
Base_dados = df_b

# %%
Base_dados.describe()
# Out:
#        Cliente_id       idade        Renda
# count  100.000000  100.000000   100.000000
# mean    50.500000   77.490000  5777.270000
# std     29.011492   11.627636  1881.480047
# min      1.000000   60.000000  2569.000000
# 25%     25.750000   68.000000  4235.750000
# 50%     50.500000   78.000000  5398.500000
# 75%     75.250000   88.250000  7547.250000
# max    100.000000   98.000000  8935.000000

# %%
Base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    int64
#  1   Remedios      100 non-null    object
#  2   Nome          100 non-null    object
#  3   idade         100 non-null    int64
#  4   Uf            100 non-null    object
#  5   Escolaridade  100 non-null    object
#  6   Renda         100 non-null    int64
#  7   Civil         100 non-null    object
#  8   Sintomas      100 non-null    object
#  9   Data          100 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 8.6+ KB

# %%
Base_dados.head()
# Out:
#    Cliente_id                                      Remedios              Nome  \
# 0           1  Azitromicina Cefalexina Losartana Alprazolam          Roth May
# 1           2             Azitromicina Cefalexina Losartana     Sharon Hebert
# 2           3                                  Azitromicina     Felix Cochran
# 3           4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz
# 4           5                       Azitromicina Cefalexina   Vielka Mcintosh
#
#    idade  Uf Escolaridade  Renda     Civil                Sintomas        Data
# 0     82  RS        Medio   6515  Separado                  Normal  2022-09-07
# 1     70  PE        Medio   5943  Separado       Lapsos_de_memoria  2023-03-29
# 2     73  PR        Medio   6264    Casado  Incontinencia_urinaria  2023-05-15
# 3     71  GO        Medio   4062  Solteiro                 Insonia  2022-11-29
# 4     61  GO        Medio   8316     Viuvo           Agressividade  2022-10-17

# %%
#Convertendo os DTypes do Dataframe de forma automática

Base_dados = Base_dados.convert_dtypes()

# %%
Base_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    Int64
#  1   Remedios      100 non-null    string
#  2   Nome          100 non-null    string
#  3   idade         100 non-null    Int64
#  4   Uf            100 non-null    string
#  5   Escolaridade  100 non-null    string
#  6   Renda         100 non-null    Int64
#  7   Civil         100 non-null    string
#  8   Sintomas      100 non-null    string
#  9   Data          100 non-null    string
# dtypes: Int64(3), string(7)
# memory usage: 8.9 KB

# %%
#Alterando o Dtype da coluna Data

Base_dados['Data'] = pd.to_datetime(Base_dados['Data'])

# %% [markdown]
# # **2.6 - Prontificando o Dataframe para Exportação em CSV**

# %%
Base_dados.info()
Base_dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    Int64
#  1   Remedios      100 non-null    string
#  2   Nome          100 non-null    string
#  3   idade         100 non-null    Int64
#  4   Uf            100 non-null    string
#  5   Escolaridade  100 non-null    string
#  6   Renda         100 non-null    Int64
#  7   Civil         100 non-null    string
#  8   Sintomas      100 non-null    string
#  9   Data          100 non-null    datetime64[ns]
# dtypes: Int64(3), datetime64[ns](1), string(6)
# memory usage: 8.9 KB
#     Cliente_id                                           Remedios  \
# 0            1       Azitromicina Cefalexina Losartana Alprazolam
# 1            2                  Azitromicina Cefalexina Losartana
# 2            3                                       Azitromicina
# 3            4       Azitromicina Cefalexina Losartana Alprazolam
# 4            5                            Azitromicina Cefalexina
# ..         ...                                                ...
# 95          96                  Azitromicina Cefalexina Losartana
# 96          97                                       Azitromicina
# 97          98  Azitromicina Cefalexina Losartana Alprazolam S...
# 98          99       Azitromicina Cefalexina Losartana Alprazolam
# 99         100       Azitromicina Cefalexina Losartana Alprazolam
#
#                 Nome  idade  Uf Escolaridade  Renda     Civil  \
# 0           Roth May     82  RS        Medio   6515  Separado
# 1      Sharon Hebert     70  PE        Medio   5943  Separado
# 2      Felix Cochran     73  PR        Medio   6264    Casado
# 3   Xanthus Schwartz     71  GO        Medio   4062  Solteiro
# 4    Vielka Mcintosh     61  GO        Medio   8316     Viuvo
# ..               ...    ...  ..          ...    ...       ...
# 95    Aquila Michael     90  RJ        Medio   6149  Separado
# 96      Natalie Cole     95  PE     Superior   4169  Separado
# 97   Hamilton Hunter     79  MG     Superior   4113    Casado
# 98         Ava Lynch     73  GO     Primario   5362  Solteiro
# 99    Minerva Alford     85  PE     Superior   3764  Solteiro
#
#                   Sintomas       Data
# 0                   Normal 2022-09-07
# 1        Lapsos_de_memoria 2023-03-29
# 2   Incontinencia_urinaria 2023-05-15
# 3                  Insonia 2022-11-29
# 4            Agressividade 2022-10-17
# ..                     ...        ...
# 95       Lapsos_de_memoria 2022-10-22
# 96                 Insonia 2022-01-04
# 97                  Vomito 2023-04-10
# 98       Lapsos_de_memoria 2023-07-09
# 99       Lapsos_de_memoria 2022-09-09
#
# [100 rows x 10 columns]

# %% [markdown]
# **2.6.1 - Exportação em CSV**

# %%
Base_dados.to_csv("/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/Base_dados_gestao.csv", sep=';', encoding='utf8', index=False)

# %% [markdown]
# # **3 - Análises**

# %%
Dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/Base_dados_gestao.csv', sep=';', encoding='utf8')

# %% [markdown]
# ***3.1 - Tratamentos para Estudos.***

# %%
#Importando bibliotecas

import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    int64
#  1   Remedios      100 non-null    object
#  2   Nome          100 non-null    object
#  3   idade         100 non-null    int64
#  4   Uf            100 non-null    object
#  5   Escolaridade  100 non-null    object
#  6   Renda         100 non-null    int64
#  7   Civil         100 non-null    object
#  8   Sintomas      100 non-null    object
#  9   Data          100 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 7.9+ KB

# %%
Dados.head(10)
# Out:
#    Cliente_id                                      Remedios              Nome  \
# 0           1  Azitromicina Cefalexina Losartana Alprazolam          Roth May
# 1           2             Azitromicina Cefalexina Losartana     Sharon Hebert
# 2           3                                  Azitromicina     Felix Cochran
# 3           4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz
# 4           5                       Azitromicina Cefalexina   Vielka Mcintosh
# 5           6                                  Azitromicina      Ivor Alvarez
# 6           7  Azitromicina Cefalexina Losartana Alprazolam   Jordan Mcdonald
# 7           8                       Azitromicina Cefalexina    Denton Cochran
# 8           9                       Azitromicina Cefalexina     Caesar Hardin
# 9          10  Azitromicina Cefalexina Losartana Alprazolam       Jack Dotson
#
#    idade  Uf Escolaridade  Renda     Civil                Sintomas        Data
# 0     82  RS        Medio   6515  Separado                  Normal  2022-09-07
# 1     70  PE        Medio   5943  Separado       Lapsos_de_memoria  2023-03-29
# 2     73  PR        Medio   6264    Casado  Incontinencia_urinaria  2023-05-15
# 3     71  GO        Medio   4062  Solteiro                 Insonia  2022-11-29
# 4     61  GO        Medio   8316     Viuvo           Agressividade  2022-10-17
# 5     60  PR     Primario   4379    Casado                 Insonia  2021-07-10
# 6     78  SP        Medio   4740    Casado       Lapsos_de_memoria  2022-07-26
# 7     80  SC        Medio   4569    Casado           Agressividade  2022-03-21
# 8     95  CE        Medio   7315     Viuvo       Lapsos_de_memoria  2023-01-01
# 9     90  MA     Primario   2985  Separado       Lapsos_de_memoria  2022-08-12

# %%
#Classificando os dados das colunas sexo, UF, Escolaridade, Civil, Sintomas

uf_class = {'RO':'1','AC':'2','AM':'3','RR':'4','PA':'5','AP':'6','TO':'7','MA':'8','PI':'9','CE':'10','RN':'11',
            'PB':'12','PE':'13','AL':'14','SE':'15','BA':'16','MG':'17','ES':'18','RJ':'19','SP':'20',
            'PR':'21','SC':'22','RS':'23','MS':'24','MT':'25','GO':'26','DF':'27'
            }


Escolaridade_class = {'Primario':1,'Medio':2,'Superior':3}

Civil_class = {'Solteiro':1,'Casado':2,'Viuvo':3,'Separado':4}

Sintomas_class = {'Normal':1,'Insonia':2,'Agressividade':3,'Quedas_de_pressao':4,'Lapsos_de_memoria':5,'Incontinencia_urinaria':6,'Vomito':7}

# %%
Dados.info(10)

# %%
#Convertendo o dataframe de forma automática para os Dtypes adequados!

Dados = Dados.convert_dtypes()

# %%
#Convertendo os dados das colunas conforme as classificações

Dados['Uf'] = Dados['Uf'].map(uf_class)
Dados['Escolaridade'] = Dados['Escolaridade'].map(Escolaridade_class)
Dados['Civil'] = Dados['Civil'].map(Civil_class)
Dados['Sintomas'] = Dados['Sintomas'].map(Sintomas_class)
Dados.head(10)
# Out:
#    Cliente_id                                      Remedios              Nome  \
# 0           1  Azitromicina Cefalexina Losartana Alprazolam          Roth May
# 1           2             Azitromicina Cefalexina Losartana     Sharon Hebert
# 2           3                                  Azitromicina     Felix Cochran
# 3           4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz
# 4           5                       Azitromicina Cefalexina   Vielka Mcintosh
# 5           6                                  Azitromicina      Ivor Alvarez
# 6           7  Azitromicina Cefalexina Losartana Alprazolam   Jordan Mcdonald
# 7           8                       Azitromicina Cefalexina    Denton Cochran
# 8           9                       Azitromicina Cefalexina     Caesar Hardin
# 9          10  Azitromicina Cefalexina Losartana Alprazolam       Jack Dotson
#
#    idade  Uf  Escolaridade  Renda  Civil  Sintomas        Data
# 0     82  23             2   6515      4         1  2022-09-07
# 1     70  13             2   5943      4         5  2023-03-29
# 2     73  21             2   6264      2         6  2023-05-15
# 3     71  26             2   4062      1         2  2022-11-29
# 4     61  26             2   8316      3         3  2022-10-17
# 5     60  21             1   4379      2         2  2021-07-10
# 6     78  20             2   4740      2         5  2022-07-26
# 7     80  22             2   4569      2         3  2022-03-21
# 8     95  10             2   7315      3         5  2023-01-01
# 9     90   8             1   2985      4         5  2022-08-12

# %%
#Convertendo o dataframe de forma automática para os Dtypes adequados!

Dados = Dados.convert_dtypes()
Dados['Data'] = pd.to_datetime(Dados['Data'])

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    Int64
#  1   Remedios      100 non-null    string
#  2   Nome          100 non-null    string
#  3   idade         100 non-null    Int64
#  4   Uf            100 non-null    string
#  5   Escolaridade  100 non-null    Int64
#  6   Renda         100 non-null    Int64
#  7   Civil         100 non-null    Int64
#  8   Sintomas      100 non-null    Int64
#  9   Data          100 non-null    datetime64[ns]
# dtypes: Int64(6), datetime64[ns](1), string(3)
# memory usage: 8.5 KB

# %%
Dados.head(10)
# Out:
#    Cliente_id                                      Remedios              Nome  \
# 0           1  Azitromicina Cefalexina Losartana Alprazolam          Roth May
# 1           2             Azitromicina Cefalexina Losartana     Sharon Hebert
# 2           3                                  Azitromicina     Felix Cochran
# 3           4  Azitromicina Cefalexina Losartana Alprazolam  Xanthus Schwartz
# 4           5                       Azitromicina Cefalexina   Vielka Mcintosh
# 5           6                                  Azitromicina      Ivor Alvarez
# 6           7  Azitromicina Cefalexina Losartana Alprazolam   Jordan Mcdonald
# 7           8                       Azitromicina Cefalexina    Denton Cochran
# 8           9                       Azitromicina Cefalexina     Caesar Hardin
# 9          10  Azitromicina Cefalexina Losartana Alprazolam       Jack Dotson
#
#    idade  Uf  Escolaridade  Renda  Civil  Sintomas       Data
# 0     82  23             2   6515      4         1 2022-09-07
# 1     70  13             2   5943      4         5 2023-03-29
# 2     73  21             2   6264      2         6 2023-05-15
# 3     71  26             2   4062      1         2 2022-11-29
# 4     61  26             2   8316      3         3 2022-10-17
# 5     60  21             1   4379      2         2 2021-07-10
# 6     78  20             2   4740      2         5 2022-07-26
# 7     80  22             2   4569      2         3 2022-03-21
# 8     95  10             2   7315      3         5 2023-01-01
# 9     90   8             1   2985      4         5 2022-08-12

# %%
#necessidade de criar uma coluna com a quantidade de remédios por cliente
lista = Dados['Remedios'].unique()
lista
# Out:
# <StringArray>
# [             'Azitromicina Cefalexina Losartana Alprazolam',
#                          'Azitromicina Cefalexina Losartana',
#                                               'Azitromicina',
#                                    'Azitromicina Cefalexina',
#  'Azitromicina Cefalexina Losartana Alprazolam Sinvastatina']
# Length: 5, dtype: string

# %%
#Cada cliente possui seus remedios e esta informação alimentará uma nova
#coluna com a quantidade dos mesmos para analises posteriores...

r1 = lista[2]
r2 = lista[3]
r3 = lista[1]
r4 = lista[0]
r5 = lista[4]

# %%
Dados['Qtde'] = Dados['Remedios'].apply(lambda x:'1' if x == r1 else '2' if x == r2 else '3' if x == r3 else '4' if x == r4 else '5' )

# %%
Dados.head(20)
# Out:
#     Cliente_id                                           Remedios  \
# 0            1       Azitromicina Cefalexina Losartana Alprazolam
# 1            2                  Azitromicina Cefalexina Losartana
# 2            3                                       Azitromicina
# 3            4       Azitromicina Cefalexina Losartana Alprazolam
# 4            5                            Azitromicina Cefalexina
# 5            6                                       Azitromicina
# 6            7       Azitromicina Cefalexina Losartana Alprazolam
# 7            8                            Azitromicina Cefalexina
# 8            9                            Azitromicina Cefalexina
# 9           10       Azitromicina Cefalexina Losartana Alprazolam
# 10          11  Azitromicina Cefalexina Losartana Alprazolam S...
# 11          12                            Azitromicina Cefalexina
# 12          13                  Azitromicina Cefalexina Losartana
# 13          14                                       Azitromicina
# 14          15                            Azitromicina Cefalexina
# 15          16                  Azitromicina Cefalexina Losartana
# 16          17       Azitromicina Cefalexina Losartana Alprazolam
# 17          18                            Azitromicina Cefalexina
# 18          19                            Azitromicina Cefalexina
# 19          20                                       Azitromicina
#
#                 Nome  idade  Uf  Escolaridade  Renda  Civil  Sintomas  \
# 0           Roth May     82  23             2   4506      4         1
# 1      Sharon Hebert     70  13             2   4194      4         2
# 2      Felix Cochran     73  21             2   2041      2         5
# 3   Xanthus Schwartz     71  26             2   5892      1         1
# 4    Vielka Mcintosh     61  26             2   3311      3         4
# 5       Ivor Alvarez     60  21             1   3227      2         4
# 6    Jordan Mcdonald     78  20             2   5344      2         2
# 7     Denton Cochran     80  22             2   1576      2         5
# 8      Caesar Hardin     95  10             2   1747      3         5
# 9        Jack Dotson     90   8             1   4086      4         2
# 10        Clark Head     98  16             3   4398      4         2
# 11      Sage Schmidt     61  10             1   3334      4         4
# 12    Castor Robbins     89  12             3   4167      2         2
# 13       Drake Frank     95  12             2   3800      2         4
# 14      Jordan Berry     94  22             2   3811      2         4
# 15       Dawn Knight     93  10             1   4730      2         2
# 16   Savannah Branch     86  20             1   4336      1         3
# 17       Declan Cruz     78   5             2   3194      4         4
# 18  Leilani Mcdaniel     64   5             1   3647      3         4
# 19    Zachary Cannon     78  19             2   2148      2         5
#
#          Data Qtde
# 0  2022-09-07    4
# 1  2023-03-29    3
# 2  2023-05-15    1
# 3  2022-11-29    4
# 4  2022-10-17    2
# 5  2021-07-10    1
# 6  2022-07-26    4
# 7  2022-03-21    2
# 8  2023-01-01    2
# 9  2022-08-12    4
# 10 2022-04-24    5
# 11 2023-03-08    2
# 12 2021-05-27    3
# 13 2021-12-02    1
# 14 2021-12-07    2
# 15 2021-11-23    3
# 16 2022-10-02    4
# 17 2021-06-17    2
# 18 2023-03-18    2
# 19 2023-09-30    1

# %%
#Alterando o tipo de dado da coluna 'Qtde'

Dados['Qtde'] = pd.to_numeric(Dados['Qtde'])

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Cliente_id    100 non-null    Int64
#  1   Remedios      100 non-null    string
#  2   Nome          100 non-null    string
#  3   idade         100 non-null    Int64
#  4   Uf            100 non-null    string
#  5   Escolaridade  100 non-null    Int64
#  6   Renda         100 non-null    int64
#  7   Civil         100 non-null    Int64
#  8   Sintomas      100 non-null    int64
#  9   Data          100 non-null    datetime64[ns]
#  10  Qtde          100 non-null    int64
# dtypes: Int64(4), datetime64[ns](1), int64(3), string(3)
# memory usage: 9.1 KB

# %% [markdown]
# ***3.2 - Manipulação de Dados***

# %%
#Manipulação 1
#Manipulando os dados com a intenção de obter correlação mais amigável e gerar insights
#A ideia é quanto maior o numero de remedios (coluna Qtde) maior o numero de sintomas.
import random

Dados['Sintomas'] = Dados['Qtde'].apply(lambda x:random.randint(1,3) if x <=3 else random.randint(4,5) if x>=4 and x<=5 else random.randint(5,7))

# %%
#Manipulação 2
#A ideia é quanto maior o numero de Sintomas menor a renda.

Dados['Renda'] = Dados['Sintomas'].apply(lambda x: random.randint(1320,2500) if x >= 5 else random.randint(2600,3900) if x<5 and x > 3 else random.randint(4000,6000))

# %%
#Alterando o tipo de dado da coluna 'Qtde'

Dados['Qtde'] = pd.to_numeric(Dados['Qtde'])

# %%
Dados.head(20)
# Out:
#     Cliente_id                                           Remedios  \
# 0            1       Azitromicina Cefalexina Losartana Alprazolam
# 1            2                  Azitromicina Cefalexina Losartana
# 2            3                                       Azitromicina
# 3            4       Azitromicina Cefalexina Losartana Alprazolam
# 4            5                            Azitromicina Cefalexina
# 5            6                                       Azitromicina
# 6            7       Azitromicina Cefalexina Losartana Alprazolam
# 7            8                            Azitromicina Cefalexina
# 8            9                            Azitromicina Cefalexina
# 9           10       Azitromicina Cefalexina Losartana Alprazolam
# 10          11  Azitromicina Cefalexina Losartana Alprazolam S...
# 11          12                            Azitromicina Cefalexina
# 12          13                  Azitromicina Cefalexina Losartana
# 13          14                                       Azitromicina
# 14          15                            Azitromicina Cefalexina
# 15          16                  Azitromicina Cefalexina Losartana
# 16          17       Azitromicina Cefalexina Losartana Alprazolam
# 17          18                            Azitromicina Cefalexina
# 18          19                            Azitromicina Cefalexina
# 19          20                                       Azitromicina
#
#                 Nome  idade  Uf  Escolaridade  Renda  Civil  Sintomas  \
# 0           Roth May     82  23             2   3112      4         4
# 1      Sharon Hebert     70  13             2   4524      4         3
# 2      Felix Cochran     73  21             2   5194      2         3
# 3   Xanthus Schwartz     71  26             2   1840      1         5
# 4    Vielka Mcintosh     61  26             2   5749      3         3
# 5       Ivor Alvarez     60  21             1   4159      2         3
# 6    Jordan Mcdonald     78  20             2   2407      2         5
# 7     Denton Cochran     80  22             2   5405      2         3
# 8      Caesar Hardin     95  10             2   5436      3         1
# 9        Jack Dotson     90   8             1   2684      4         4
# 10        Clark Head     98  16             3   3648      4         4
# 11      Sage Schmidt     61  10             1   5986      4         2
# 12    Castor Robbins     89  12             3   4849      2         1
# 13       Drake Frank     95  12             2   4717      2         2
# 14      Jordan Berry     94  22             2   5206      2         1
# 15       Dawn Knight     93  10             1   4595      2         2
# 16   Savannah Branch     86  20             1   1602      1         5
# 17       Declan Cruz     78   5             2   5664      4         3
# 18  Leilani Mcdaniel     64   5             1   5397      3         1
# 19    Zachary Cannon     78  19             2   5255      2         3
#
#          Data  Qtde
# 0  2022-09-07     4
# 1  2023-03-29     3
# 2  2023-05-15     1
# 3  2022-11-29     4
# 4  2022-10-17     2
# 5  2021-07-10     1
# 6  2022-07-26     4
# 7  2022-03-21     2
# 8  2023-01-01     2
# 9  2022-08-12     4
# 10 2022-04-24     5
# 11 2023-03-08     2
# 12 2021-05-27     3
# 13 2021-12-02     1
# 14 2021-12-07     2
# 15 2021-11-23     3
# 16 2022-10-02     4
# 17 2021-06-17     2
# 18 2023-03-18     2
# 19 2023-09-30     1

# %%
Dados.describe()

# %%
Dados.info()

# %%
Dados.info()

# %% [markdown]
# # **3.3 - Análise de correlação**

# %%
sns.heatmap(Dados.corr(method='pearson'), annot=True, fmt=".1f", linewidths=.6)
# Out:
# <ipython-input-437-d9f389f2dc49>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Dados.corr(method='pearson'), annot=True, fmt=".1f", linewidths=.6)
# <Axes: >

# %% [markdown]
# # **3.4 - Gráficos de linhas**

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,5))
fig.suptitle("Análise  gráfica")
axes[0].set_title("Qtde de Remédios X Renda")
axes[1].set_title("Sintomas X Renda")
sns.lineplot(data = Dados, x= 'Renda', y='Qtde', color = "red",ax=axes[0])
sns.regplot( data= Dados, x = "Renda", y= "Sintomas",ax=axes[1])
# Out:
# <Axes: title={'center': 'Sintomas X Renda'}, xlabel='Renda', ylabel='Sintomas'>

# %% [markdown]
# # **3.5 - Análise de remédios - Histograma**

# %%
col_remedios = Dados['Remedios']
col_remedios = pd.DataFrame(col_remedios)

# %%
col_remedios.head(10)
# Out:
#                                        Remedios
# 0  Azitromicina Cefalexina Losartana Alprazolam
# 1             Azitromicina Cefalexina Losartana
# 2                                  Azitromicina
# 3  Azitromicina Cefalexina Losartana Alprazolam
# 4                       Azitromicina Cefalexina
# 5                                  Azitromicina
# 6  Azitromicina Cefalexina Losartana Alprazolam
# 7                       Azitromicina Cefalexina
# 8                       Azitromicina Cefalexina
# 9  Azitromicina Cefalexina Losartana Alprazolam

# %%
#Contagem dos remédios

Azitromicina = col_remedios.apply(lambda x:x.str.contains('Azitromicina').sum()).sum()
Cefalexina = col_remedios.apply(lambda x:x.str.contains('Cefalexina').sum()).sum()
Losartana = col_remedios.apply(lambda x:x.str.contains('Losartana').sum()).sum()
Alprazolam = col_remedios.apply(lambda x:x.str.contains('Alprazolam').sum()).sum()
Sinvastatina = col_remedios.apply(lambda x:x.str.contains('Sinvastatina').sum()).sum()

# %%
#Criando um Dataframe
Estats_remedios = pd.DataFrame({
    'Remedio':['Azitromicina','Cefalexina','Losartana','Alprazolam','Sinvastatina'],
    'Total':[Azitromicina,Cefalexina,Losartana,Alprazolam,Sinvastatina]
})

# %%
Estats_remedios.convert_dtypes()
# Out:
#         Remedio  Total
# 0  Azitromicina    100
# 1    Cefalexina     87
# 2     Losartana     57
# 3    Alprazolam     40
# 4  Sinvastatina      9

# %%
plt.hist(Dados['Qtde'], bins=5, color='blue', edgecolor='black',cumulative=True )
plt.title('Qtde de Remédios X Clientes')
plt.xlabel('Qtde de Remédios')
plt.ylabel('Qtde de Clientes')
plt.show()

# %% [markdown]
# # **4 - Análise de um cliente**

# %%
#Carregamendo do Google drive para leitura dos Datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %% [markdown]
# ***4.1 - Carregamento dos dados e Tratamento***

# %%
tab_comportamentos_xls = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/registro_comportamentos.xlsx')
tab_fraldas = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/registro_fraldas.xlsx')
tab_medicamentos_xls = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/XP_PA/Datasets/registro_medicamentos.xlsx')

# %%
tab_medicamentos_xls.head(10)
# Out:
#         DATA  m_1  m_2  m_3  m_4  m_5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0 2023-01-02    1    1    0    1    1         NaN         NaN         NaN
# 1 2023-01-03    1    1    0    1    1         NaN         NaN         NaN
# 2 2023-01-04    1    1    0    1    1         NaN         NaN         NaN
# 3 2023-01-05    1    1    0    1    1         NaN         NaN         NaN
# 4 2023-01-06    1    1    0    1    1         NaN         NaN         NaN
# 5 2023-01-07    1    1    0    1    1         NaN         NaN         NaN
# 6 2023-01-08    1    1    0    1    1         NaN         NaN         NaN
# 7 2023-01-09    1    1    0    1    1         NaN         NaN         NaN
# 8 2023-01-10    1    1    0    1    1         NaN         NaN         NaN
# 9 2023-01-11    1    1    0    1    1         NaN         NaN         NaN
#
#   Unnamed: 9
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8          /
# 9        NaN

# %%
#Excluindo as colunas desnecessárias

tab_medicamentos_xls = tab_medicamentos_xls.drop(columns=['Unnamed: 6', 'Unnamed: 7','Unnamed: 8','Unnamed: 9'])
tab_medicamentos_xls.head(10)
# Out:
#         DATA  m_1  m_2  m_3  m_4  m_5
# 0 2023-01-02    1    1    0    1    1
# 1 2023-01-03    1    1    0    1    1
# 2 2023-01-04    1    1    0    1    1
# 3 2023-01-05    1    1    0    1    1
# 4 2023-01-06    1    1    0    1    1
# 5 2023-01-07    1    1    0    1    1
# 6 2023-01-08    1    1    0    1    1
# 7 2023-01-09    1    1    0    1    1
# 8 2023-01-10    1    1    0    1    1
# 9 2023-01-11    1    1    0    1    1

# %%
#Tratando a coluna DATA das tabelas para posteriormente,
#concatenar e formar uma base de dados só.


tab_comportamentos_xls["DATA"]= pd.to_datetime(tab_comportamentos_xls["DATA"])
tab_comportamentos_xls["DATA"].dt.strftime('%Y-%m-%d')

tab_fraldas["DATA"]= pd.to_datetime(tab_fraldas["DATA"])
tab_comportamentos_xls["DATA"].dt.strftime('%Y-%m-%d')
# Out:
# 0      2023-01-02
# 1      2023-01-03
# 2      2023-01-04
# 3      2023-01-05
# 4      2023-01-06
#           ...
# 462    2024-04-08
# 463    2024-04-09
# 464    2024-04-10
# 465    2024-04-11
# 466    2024-04-12
# Name: DATA, Length: 467, dtype: object

# %% [markdown]
# ***4.2 - Unindo as tabelas.***

# %%
df_a = pd.merge(tab_comportamentos_xls, tab_fraldas, on=['DATA'], how='inner')
df_a
# Out:
#           DATA  c_a  f_1  f_2
# 0   2023-01-02    1    4    1
# 1   2023-01-03    1    3    1
# 2   2023-01-04    1    3    1
# 3   2023-01-05    0    3    1
# 4   2023-01-06    0    4    1
# ..         ...  ...  ...  ...
# 462 2024-04-08    0    5    1
# 463 2024-04-09    0    5    1
# 464 2024-04-10    0    4    1
# 465 2024-04-11    0    3    1
# 466 2024-04-12    1    4    1
#
# [467 rows x 4 columns]

# %%
Dados_cliente = pd.merge(df_a, tab_medicamentos_xls, on=['DATA'], how='inner')
Dados_cliente.head(10)
# Out:
#         DATA  c_a  f_1  f_2  m_1  m_2  m_3  m_4  m_5
# 0 2023-01-02    1    4    1    1    1    0    1    1
# 1 2023-01-03    1    3    1    1    1    0    1    1
# 2 2023-01-04    1    3    1    1    1    0    1    1
# 3 2023-01-05    0    3    1    1    1    0    1    1
# 4 2023-01-06    0    4    1    1    1    0    1    1
# 5 2023-01-07    1    4    1    1    1    0    1    1
# 6 2023-01-08    0    3    1    1    1    0    1    1
# 7 2023-01-09    0    4    1    1    1    0    1    1
# 8 2023-01-10    1    4    1    1    1    0    1    1
# 9 2023-01-11    0    3    1    1    1    0    1    1

# %%
#Renomeando as colunas
Dados_cliente.columns=['Mes',	'Anormal','f_Diaria',	'f_Noturna',	'm_1',	'm_2',	'm_3',	'm_4','m_5']

# %%
Dados_cliente
# Out:
#            Mes  Anormal  f_Diaria  f_Noturna  m_1  m_2  m_3  m_4  m_5
# 0   2023-01-02        1         4          1    1    1    0    1    1
# 1   2023-01-03        1         3          1    1    1    0    1    1
# 2   2023-01-04        1         3          1    1    1    0    1    1
# 3   2023-01-05        0         3          1    1    1    0    1    1
# 4   2023-01-06        0         4          1    1    1    0    1    1
# ..         ...      ...       ...        ...  ...  ...  ...  ...  ...
# 462 2024-04-08        0         5          1    1    1    0    1    1
# 463 2024-04-09        0         5          1    1    1    0    1    1
# 464 2024-04-10        0         4          1    1    1    0    1    1
# 465 2024-04-11        0         3          1    1    1    0    1    1
# 466 2024-04-12        1         4          1    1    1    0    1    1
#
# [467 rows x 9 columns]

# %%
#Indexando
Dados_cliente.index = Dados['Mes']

# %%
#Após o index, dropando a coluna duplicada
Dados_cliente = Dados_cliente.drop(columns=['Mes'])

# %%
#Modificando o DF
Dados_cliente = Dados_cliente.groupby(pd.Grouper(freq='M')).sum()

#Criando um Df só com as médias para qualquer utilidade.
Dados_cliente_media = Dados_cliente.groupby(pd.Grouper(freq='M')).mean()

# %%
#Verificando
Dados_cliente.head(20)
# Out:
#             Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Mes
# 2023-01-31      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-02-28      0.0     100.0       28.0  28.0  28.0   0.0  28.0  28.0
# 2023-03-31      5.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-04-30      6.0     105.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-05-31      7.0     103.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-06-30      7.0     104.0       30.0  30.0  30.0   0.0  30.0  18.0
# 2023-07-31      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-08-31      0.0     114.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-09-30     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# 2023-10-31     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# 2023-11-30      7.0     104.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-12-31      7.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-01-31      6.0     132.0       52.0  31.0  31.0   0.0  31.0  31.0
# 2024-02-29     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# 2024-03-31     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-04-30      1.0      49.0       12.0  12.0  12.0   0.0  12.0  12.0

# %%
Dados_cliente_media.head(20)
# Out:
#             Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Mes
# 2023-01-31      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-02-28      0.0     100.0       28.0  28.0  28.0   0.0  28.0  28.0
# 2023-03-31      5.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-04-30      6.0     105.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-05-31      7.0     103.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-06-30      7.0     104.0       30.0  30.0  30.0   0.0  30.0  18.0
# 2023-07-31      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-08-31      0.0     114.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-09-30     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# 2023-10-31     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# 2023-11-30      7.0     104.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-12-31      7.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-01-31      6.0     132.0       52.0  31.0  31.0   0.0  31.0  31.0
# 2024-02-29     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# 2024-03-31     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-04-30      1.0      49.0       12.0  12.0  12.0   0.0  12.0  12.0

# %% [markdown]
# ***4.3 - Modificações na coluna Mês: de Data completa para somente o Mês***

# %%
#Criando uma lista com meses

Meses = ['Jan23','Fev23','Mar23','Abr23','Mai23','Jun23','Jul23','Ago23','Set23','Out23','Nov23','Dez23','Jan24','Fev24','Mar24','Abr24']

# %%
#Inserindo a nova coluna com os Meses
Dados_cliente.insert(0,'Meses',Meses,True)
Dados_cliente_media.insert(0,'Meses', Meses, True)

# %%
Dados_cliente.head(20)
# Out:
#             Meses  Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Mes
# 2023-01-31  Jan23      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-02-28  Fev23      0.0     100.0       28.0  28.0  28.0   0.0  28.0  28.0
# 2023-03-31  Mar23      5.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-04-30  Abr23      6.0     105.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-05-31  Mai23      7.0     103.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2023-06-30  Jun23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  18.0
# 2023-07-31  Jul23      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-08-31  Ago23      0.0     114.0       31.0  31.0  31.0   0.0  31.0  28.0
# 2023-09-30  Set23     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# 2023-10-31  Out23     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# 2023-11-30  Nov23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  30.0
# 2023-12-31  Dez23      7.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-01-31  Jan24      6.0     132.0       52.0  31.0  31.0   0.0  31.0  31.0
# 2024-02-29  Fev24     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# 2024-03-31  Mar24     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0
# 2024-04-30  Abr24      1.0      49.0       12.0  12.0  12.0   0.0  12.0  12.0

# %%
Dados_cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16 entries, 2023-01-31 to 2024-04-30
# Freq: M
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Meses      16 non-null     object
#  1   Anormal    16 non-null     float64
#  2   f_Diaria   16 non-null     float64
#  3   f_Noturna  16 non-null     float64
#  4   m_1        16 non-null     float64
#  5   m_2        16 non-null     float64
#  6   m_3        16 non-null     float64
#  7   m_4        16 non-null     float64
#  8   m_5        16 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 1.2+ KB

# %%
#Removendo o a coluna INDEX
Dados_cliente = Dados_cliente.reset_index(drop=True)
Dados_cliente_media = Dados_cliente_media.reset_index(drop=True)

# %%
Dados_cliente = Dados_cliente.set_index('Meses')
Dados_cliente_media = Dados_cliente_media.set_index('Meses')

# %% [markdown]
# ***4.4 - Prontificando o DF para estudos***

# %%
#Verificando
Dados_cliente.head(20)
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Meses
# Jan23      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# Fev23      0.0     100.0       28.0  28.0  28.0   0.0  28.0  28.0
# Mar23      5.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# Abr23      6.0     105.0       30.0  30.0  30.0   0.0  30.0  30.0
# Mai23      7.0     103.0       31.0  31.0  31.0   0.0  31.0  31.0
# Jun23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  18.0
# Jul23      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# Ago23      0.0     114.0       31.0  31.0  31.0   0.0  31.0  28.0
# Set23     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# Out23     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# Nov23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  30.0
# Dez23      7.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# Jan24      6.0     132.0       52.0  31.0  31.0   0.0  31.0  31.0
# Fev24     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# Mar24     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0
# Abr24      1.0      49.0       12.0  12.0  12.0   0.0  12.0  12.0

# %%
Dados_cliente_media.head(20)
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Meses
# Jan23      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# Fev23      0.0     100.0       28.0  28.0  28.0   0.0  28.0  28.0
# Mar23      5.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# Abr23      6.0     105.0       30.0  30.0  30.0   0.0  30.0  30.0
# Mai23      7.0     103.0       31.0  31.0  31.0   0.0  31.0  31.0
# Jun23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  18.0
# Jul23      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# Ago23      0.0     114.0       31.0  31.0  31.0   0.0  31.0  28.0
# Set23     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# Out23     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# Nov23      7.0     104.0       30.0  30.0  30.0   0.0  30.0  30.0
# Dez23      7.0     109.0       31.0  31.0  31.0   0.0  31.0  31.0
# Jan24      6.0     132.0       52.0  31.0  31.0   0.0  31.0  31.0
# Fev24     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# Mar24     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0
# Abr24      1.0      49.0       12.0  12.0  12.0   0.0  12.0  12.0

# %%
Dados_cliente_media.describe()
# Out:
#          Anormal    f_Diaria  f_Noturna        m_1        m_2      m_3  \
# count  16.000000   16.000000  16.000000  16.000000  16.000000  16.0000
# mean    7.125000  106.625000  31.312500  29.875000  29.187500   0.9375
# std     4.558874   17.606344   8.113518   8.484299   4.665029   3.7500
# min     0.000000   49.000000  12.000000  12.000000  12.000000   0.0000
# 25%     5.750000  104.000000  30.000000  30.000000  30.000000   0.0000
# 50%     7.000000  108.500000  30.500000  30.500000  30.500000   0.0000
# 75%     8.500000  111.000000  31.000000  31.000000  31.000000   0.0000
# max    17.000000  132.000000  52.000000  54.000000  31.000000  15.0000
#
#             m_4        m_5
# count  16.00000  16.000000
# mean   26.75000  25.312500
# std     8.20975   7.282113
# min     4.00000  12.000000
# 25%    29.50000  17.750000
# 50%    30.00000  29.000000
# 75%    31.00000  31.000000
# max    31.00000  31.000000

# %% [markdown]
# # **5 - Análises**

# %% [markdown]
# # *5.1 - Correlação*

# %%
#teste = Dados.corr()
sns.heatmap(Dados_cliente_media.corr(method='pearson'), annot=True, fmt=".1f", linewidths=.6)
# Out:
# <Axes: >

# %% [markdown]
# # *Olhando mais de perto as variáveis com correlação 0.4, 0.5 e 0.6, as correlações entre o Comportamento Anormal, qtde fraldas do tipo 1, medicamento tipo 1 e medicamento tipo 3, chamam a atenção e veremos algum insight nos gráficos*

# %%
Dados_cliente_media_b = Dados_cliente_media.drop(columns=['m_2','m_4'])
Dados_cliente_media_b.head(10)
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_3   m_5
# Meses
# Jan23      8.0     107.0       30.0  30.0   0.0  30.0
# Fev23      0.0     100.0       28.0  28.0   0.0  28.0
# Mar23      5.0     109.0       31.0  31.0   0.0  31.0
# Abr23      6.0     105.0       30.0  30.0   0.0  30.0
# Mai23      7.0     103.0       31.0  31.0   0.0  31.0
# Jun23      7.0     104.0       30.0  30.0   0.0  18.0
# Jul23      8.0     109.0       31.0  31.0   0.0  28.0
# Ago23      0.0     114.0       31.0  31.0   0.0  28.0
# Set23     12.0     108.0       30.0  30.0   0.0  17.0
# Out23     17.0     110.0       44.0  17.0  15.0  17.0

# %%
#Mapa de calor
sns.heatmap(Dados_cliente_media_b.corr(method='pearson'), annot=True, fmt=".1f", linewidths=.6)
# Out:
# <Axes: >

# %% [markdown]
# # *5.2 - Análise com gráfico de linhas*

# %%
#Buscando alterações de comportamento ao longo do tempo.

Dados_media_grafico = pd.DataFrame(Dados_cliente_media_b.reset_index())

plt.subplots(figsize=(15,4))
plt.title("Média de Comportamentos ao longo do tempo", fontsize=15)
plt.plot(Dados_media_grafico['Meses'], Dados_media_grafico['Anormal'],label='Anormal')
plt.plot(Dados_media_grafico['Meses'], Dados_media_grafico['m_1'],label='Medicamento 1')
plt.plot(Dados_media_grafico['Meses'], Dados_media_grafico['f_Diaria'],label='Fralda Diaria')
plt.plot(Dados_media_grafico['Meses'], Dados_media_grafico['f_Noturna'],label='Fralda Noturna')
plt.plot(Dados_media_grafico['Meses'], Dados_media_grafico['m_3'],label='Medicamento 3')

plt.legend()
plt.show()

# %% [markdown]
# # *5.3 - Com o gráfico de linhas expondo alguns insights, Aprofunda-se com o mapa de calor.*

# %%
#Puxando o Dataframe com o somatório por mês.
Dados_cliente.head()
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_2  m_3   m_4   m_5
# Meses
# Jan23      8.0     107.0       30.0  30.0  30.0  0.0  30.0  30.0
# Fev23      0.0     100.0       28.0  28.0  28.0  0.0  28.0  28.0
# Mar23      5.0     109.0       31.0  31.0  31.0  0.0  31.0  31.0
# Abr23      6.0     105.0       30.0  30.0  30.0  0.0  30.0  30.0
# Mai23      7.0     103.0       31.0  31.0  31.0  0.0  31.0  31.0

# %%
 #Aplicando um filtro somente com os meses que possuem ANOMALIAS ACIMA da MEDIANA
 #da sua coluna.

 Anormal_filtro = Dados_cliente.loc[(Dados_cliente['Anormal']) > Dados_cliente['Anormal'].median()]

 #Mapa de calor
 sns.heatmap(Anormal_filtro.corr(method='pearson'), annot=True, fmt=".1f", linewidths=.6)
# Out:
# <Axes: >

# %%
Anormal_filtro.describe()
# Out:
#          Anormal    f_Diaria  f_Noturna        m_1        m_2        m_3  \
# count   6.000000    6.000000   6.000000   6.000000   6.000000   6.000000
# mean   11.333333  112.833333  32.500000  32.166667  30.333333   2.500000
# std     3.444803    7.935154   5.683309  11.990274   0.816497   6.123724
# min     8.000000  107.000000  29.000000  17.000000  29.000000   0.000000
# 25%     8.500000  108.250000  30.000000  30.000000  30.000000   0.000000
# 50%    11.000000  109.500000  30.500000  30.500000  30.500000   0.000000
# 75%    12.750000  113.750000  31.000000  31.000000  31.000000   0.000000
# max    17.000000  128.000000  44.000000  54.000000  31.000000  15.000000
#
#              m_4        m_5
# count   6.000000   6.000000
# mean   23.833333  22.500000
# std    11.125047   8.117881
# min     4.000000  12.000000
# 25%    20.250000  17.000000
# 50%    30.000000  22.500000
# 75%    30.750000  29.500000
# max    31.000000  31.000000

# %%
Anormal_filtro
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Meses
# Jan23      8.0     107.0       30.0  30.0  30.0   0.0  30.0  30.0
# Jul23      8.0     109.0       31.0  31.0  31.0   0.0  31.0  28.0
# Set23     12.0     108.0       30.0  30.0  30.0   0.0  30.0  17.0
# Out23     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0
# Fev24     13.0     115.0       29.0  54.0  29.0   0.0   4.0  12.0
# Mar24     10.0     128.0       31.0  31.0  31.0   0.0  31.0  31.0

# %% [markdown]
# # *5.4 - Com filtro aplicado, Qual o mês com maior anormalidade ?*

# %%
#Anormal

Anormal_filtro.loc[Anormal_filtro['Anormal'] == Anormal_filtro['Anormal'].max()]
# Out:
#        Anormal  f_Diaria  f_Noturna   m_1   m_2   m_3   m_4   m_5
# Meses
# Out23     17.0     110.0       44.0  17.0  31.0  15.0  17.0  17.0

# %%
...Continua
